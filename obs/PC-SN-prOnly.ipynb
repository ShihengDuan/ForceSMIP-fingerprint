# %%
import xarray as xa
import pickle
from matplotlib import pyplot as plt
import numpy as np
from scipy.stats import pearsonr
import seaborn as sns
import matplotlib as mpl
mpl.rc('font', family='DejaVu Serif') 
from matplotlib.gridspec import GridSpec

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-False-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_GPCP_month = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_GPCP_month_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-True-unforced-True-joint-False', 'rb') as pfile:
    metrics_GPCP_month_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-False-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_GPCP = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_GPCP_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-False-unforced-True-joint-False', 'rb') as pfile:
    metrics_GPCP_unforced = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-False-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_MSWEP_month = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_MSWEP_month_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-True-unforced-True-joint-False', 'rb') as pfile:
    metrics_MSWEP_month_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-False-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_MSWEP = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_MSWEP_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-False-unforced-True-joint-False', 'rb') as pfile:
    metrics_MSWEP_unforced = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-False-month-True-unforced-False-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    metrics_MSWEP_month_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-True-unforced-False-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    metrics_MSWEP_month_stand_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-True-unforced-True-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    metrics_MSWEP_month_unforced_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-False-month-False-unforced-False-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    metrics_MSWEP_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-False-unforced-False-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    metrics_MSWEP_stand_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-False-unforced-True-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    metrics_MSWEP_unforced_eof2 = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-False-month-True-unforced-False-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    metrics_GPCP_month_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-True-unforced-False-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    metrics_GPCP_month_stand_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-True-unforced-True-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    metrics_GPCP_month_unforced_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-False-month-False-unforced-False-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    metrics_GPCP_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-False-unforced-False-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    metrics_GPCP_stand_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-False-unforced-True-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    metrics_GPCP_unforced_eof2 = pickle.load(pfile)

# %%
x = np.arange(len(metrics_GPCP_month['obs_pc']))
y = metrics_GPCP_month['pc']
y1 = metrics_GPCP_month['obs_pc']
r, p = pearsonr(y, y1)
plt.plot(x, y1, label='GPCP '+str(round(r, 2)))

plt.plot(x, y, label='CMIP6')
plt.legend()
plt.show()

# %%
def get_detection_time(data):# sn
    data = xa.DataArray(data, dims=['time'], coords={'time': np.arange(len(data))})
    data = data.reindex(time=list(reversed(data.time)))
    indices = (data < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = data.time.shape[0]
    back = whole_period-first_indices
    return back.data

# %% [markdown]
# # Land

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-False-month-True-unforced-False-joint-False'+'-n_mode-'+str(2)+'-REGEN-mask', 'rb') as pfile:
    land_GPCP_month_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-True-unforced-False-joint-False'+'-n_mode-'+str(2)+'-REGEN-mask', 'rb') as pfile:
    land_GPCP_month_stand_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-True-unforced-True-joint-False'+'-n_mode-'+str(2)+'-REGEN-mask', 'rb') as pfile:
    land_GPCP_month_unforced_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-False-month-False-unforced-False-joint-False'+'-n_mode-'+str(2)+'-REGEN-mask', 'rb') as pfile:
    land_GPCP_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-False-unforced-False-joint-False'+'-n_mode-'+str(2)+'-REGEN-mask', 'rb') as pfile:
    land_GPCP_stand_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-False-unforced-True-joint-False'+'-n_mode-'+str(2)+'-REGEN-mask', 'rb') as pfile:
    land_GPCP_unforced_eof2 = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-False-month-True-unforced-False-joint-False'+'-REGEN-mask', 'rb') as pfile:
    land_GPCP_month = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-True-unforced-False-joint-False'+'-REGEN-mask', 'rb') as pfile:
    land_GPCP_month_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-True-unforced-True-joint-False'+'-REGEN-mask', 'rb') as pfile:
    land_GPCP_month_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-False-month-False-unforced-False-joint-False'+'-REGEN-mask', 'rb') as pfile:
    land_GPCP = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-False-unforced-False-joint-False'+'-REGEN-mask', 'rb') as pfile:
    land_GPCP_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-False-unforced-True-joint-False'+'-REGEN-mask', 'rb') as pfile:
    land_GPCP_unforced = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-False-month-True-unforced-False-joint-False'+'-n_mode-'+str(2)+'-REGEN-mask', 'rb') as pfile:
    land_MSWEP_month_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-True-unforced-False-joint-False'+'-n_mode-'+str(2)+'-REGEN-mask', 'rb') as pfile:
    land_MSWEP_month_stand_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-True-unforced-True-joint-False'+'-n_mode-'+str(2)+'-REGEN-mask', 'rb') as pfile:
    land_MSWEP_month_unforced_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-False-month-False-unforced-False-joint-False'+'-n_mode-'+str(2)+'-REGEN-mask', 'rb') as pfile:
    land_MSWEP_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-False-unforced-False-joint-False'+'-n_mode-'+str(2)+'-REGEN-mask', 'rb') as pfile:
    land_MSWEP_stand_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-False-unforced-True-joint-False'+'-n_mode-'+str(2)+'-REGEN-mask', 'rb') as pfile:
    land_MSWEP_unforced_eof2 = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-False-month-True-unforced-False-joint-False'+'-REGEN-mask', 'rb') as pfile:
    land_MSWEP_month = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-True-unforced-False-joint-False'+'-REGEN-mask', 'rb') as pfile:
    land_MSWEP_month_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-True-unforced-True-joint-False'+'-REGEN-mask', 'rb') as pfile:
    land_MSWEP_month_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-False-month-False-unforced-False-joint-False'+'-REGEN-mask', 'rb') as pfile:
    land_MSWEP = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-False-unforced-False-joint-False'+'-REGEN-mask', 'rb') as pfile:
    land_MSWEP_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-False-unforced-True-joint-False'+'-REGEN-mask', 'rb') as pfile:
    land_MSWEP_unforced = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-False-month-True-unforced-False-joint-False', 'rb') as pfile:
    land_REGEN_month = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-True-month-True-unforced-False-joint-False', 'rb') as pfile:
    land_REGEN_month_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-True-month-True-unforced-True-joint-False', 'rb') as pfile:
    land_REGEN_month_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-False-month-False-unforced-False-joint-False', 'rb') as pfile:
    land_REGEN = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-True-month-False-unforced-False-joint-False', 'rb') as pfile:
    land_REGEN_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-True-month-False-unforced-True-joint-False', 'rb') as pfile:
    land_REGEN_unforced = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-False-month-True-unforced-False-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    land_REGEN_month_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-True-month-True-unforced-False-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    land_REGEN_month_stand_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-True-month-True-unforced-True-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    land_REGEN_month_unforced_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-False-month-False-unforced-False-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    land_REGEN_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-True-month-False-unforced-False-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    land_REGEN_stand_eof2 = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-True-month-False-unforced-True-joint-False'+'-n_mode-'+str(2), 'rb') as pfile:
    land_REGEN_unforced_eof2 = pickle.load(pfile)

# %% [markdown]
# # PC

# %%
colors = sns.color_palette('deep', 6)
GPCP_color = colors[2]
MSWEP_color = colors[-2]
REGEN_color = colors[-1]
x = np.arange(len(metrics_GPCP['pc']))
time = metrics_GPCP['pc'].time[:]
x_ticks = np.arange(40, 852, 200)
start_month = np.datetime64('1983-01')
tick_time = [start_month+np.timedelta64(i,'M') for i in x_ticks]
def plot_pc(data, color, label, ax, ref):
    x = np.arange(len(data))
    r, p = pearsonr(data, ref)
    ax.plot(x, data, label=label+' '+str(round(r, 2)), color=color)
    
# fig, axes = plt.subplots(nrows=4, ncols=3, sharey=False, sharex='row', figsize=(8, 10))
fig = plt.figure(figsize=(8, 10))
gs = GridSpec(figure=fig, nrows=5, ncols=3, height_ratios=[1, 1, .01, 1, 1])
# ax = axes.flatten()[0]
ax = fig.add_subplot(gs[0, 0])
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(metrics_GPCP['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP['pc'])
plot_pc(metrics_MSWEP['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP['pc'])
ax.plot(x, metrics_GPCP['pc'], color='black')
slope, b =np.polyfit(x, metrics_GPCP['pc'], deg=1)
ax.set_title('S-INV RawAnomaly EOF1')
ax.legend()

# ax = axes.flatten()[1]
ax = fig.add_subplot(gs[0, 1])
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(metrics_GPCP_eof2['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_eof2['pc'])
plot_pc(metrics_MSWEP_eof2['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_eof2['pc'])
ax.plot(x, metrics_GPCP_eof2['pc'], color='black')
slope, b =np.polyfit(x, metrics_GPCP['pc'], deg=1)
ax.set_title('S-INV RawAnomaly EOF2')
ax.legend()

# ax = axes.flatten()[2]
ax = fig.add_subplot(gs[0, 2])
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(metrics_GPCP_stand['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_stand['pc'])
plot_pc(metrics_MSWEP_stand['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_stand['pc'])
ax.plot(x, metrics_GPCP_stand['pc'], color='black')
slope, b =np.polyfit(x, metrics_GPCP_stand['pc'], deg=1)
ax.set_title('S-INV StdAnomaly EOF1')
ax.legend()

# ax = axes.flatten()[3]
ax = fig.add_subplot(gs[1, 0])
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(metrics_GPCP_month['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_month['pc'])
plot_pc(metrics_MSWEP_month['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_month['pc'])
ax.plot(x, metrics_GPCP_month['pc'], color='black')
slope, b =np.polyfit(x, metrics_GPCP_month['pc'], deg=1)
ax.set_title('S-VAR RawAnomaly EOF1')
ax.legend()

# ax = axes.flatten()[4]
ax = fig.add_subplot(gs[1, 1])
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(metrics_GPCP_month_eof2['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_month_eof2['pc'])
plot_pc(metrics_MSWEP_month_eof2['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_month_eof2['pc'])
ax.plot(x, metrics_GPCP_month_eof2['pc'], color='black')
slope, b =np.polyfit(x, metrics_GPCP_month['pc'], deg=1)
ax.set_title('S-VAR RawAnomaly EOF2')
ax.legend()

# ax = axes.flatten()[5]
ax = fig.add_subplot(gs[1, 2])
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(metrics_GPCP_month_stand['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_month_stand['pc'])
plot_pc(metrics_MSWEP_month_stand['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_month_stand['pc'])
ax.plot(x, metrics_GPCP_month_stand['pc'], color='black')
slope, b =np.polyfit(x, metrics_GPCP_month_stand['pc'], deg=1)
ax.set_title('S-VAR StdAnomaly EOF1')
ax.legend()

# land
x = np.arange(len(land_MSWEP_month_stand['pc']))
time = land_MSWEP_month_stand['pc'].time[:]
x_ticks = np.arange(40, 852, 180)
start_month = np.datetime64('1983-01')
tick_time = [start_month+np.timedelta64(i,'M') for i in x_ticks]
# ax = axes.flatten()[6]
ax = fig.add_subplot(gs[3, 0])
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(land_GPCP['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=land_MSWEP['pc'])
plot_pc(land_MSWEP['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=land_MSWEP['pc'])
plot_pc(land_REGEN['obs_pc'], color=REGEN_color, label='REGEN', ax=ax, ref=land_MSWEP['pc'])
ax.plot(x, land_MSWEP['pc'], color='black')
slope, b =np.polyfit(x, land_MSWEP['pc'], deg=1)
ax.set_title('S-INV RawAnomaly EOF1')
ax.legend()

# ax = axes.flatten()[7]
ax = fig.add_subplot(gs[3, 1])
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(land_GPCP_eof2['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=land_GPCP_eof2['pc'])
plot_pc(land_MSWEP_eof2['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=land_GPCP_eof2['pc'])
plot_pc(land_REGEN_eof2['obs_pc'], color=REGEN_color, label='REGEN', ax=ax, ref=land_REGEN_eof2['pc'])
ax.plot(x, land_REGEN_eof2['pc'], color='black')
slope, b =np.polyfit(x, land_REGEN_eof2['pc'], deg=1)
ax.set_title('S-INV RawAnomaly EOF2')
ax.legend()


# ax = axes.flatten()[8]
ax = fig.add_subplot(gs[3, 2])
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(land_GPCP_stand['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=land_GPCP_stand['pc'])
plot_pc(land_MSWEP_stand['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=land_MSWEP_stand['pc'])
plot_pc(land_REGEN_stand['obs_pc'], color=REGEN_color, label='REGEN', ax=ax, ref=land_REGEN_stand['pc'])
ax.plot(x, land_MSWEP_stand['pc'], color='black')
slope, b =np.polyfit(x, land_MSWEP_stand['pc'], deg=1)
ax.set_title('S-INV StdAnomaly EOF1')
ax.legend()

# ax = axes.flatten()[9]
ax = fig.add_subplot(gs[4, 0])
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(land_GPCP_month_eof2['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=land_MSWEP_month_eof2['pc'])
plot_pc(land_MSWEP_month_eof2['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=land_MSWEP_month_eof2['pc'])
plot_pc(land_REGEN_month['obs_pc'], color=REGEN_color, label='REGEN', ax=ax, ref=land_REGEN_month['pc'])
ax.plot(x, land_REGEN_month['pc'], color='black')
slope, b =np.polyfit(x, land_REGEN_month['pc'], deg=1)
ax.set_title('S-VAR RawAnomaly EOF1')
ax.legend()

# ax = axes.flatten()[10]
ax = fig.add_subplot(gs[4, 1])
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(land_GPCP_month_eof2['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=land_MSWEP_month_eof2['pc'])
plot_pc(land_MSWEP_month_eof2['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=land_MSWEP_month_eof2['pc'])
plot_pc(land_REGEN_month_eof2['obs_pc'], color=REGEN_color, label='REGEN', ax=ax, ref=land_REGEN_month_eof2['pc'])
ax.plot(x, land_REGEN_month_eof2['pc'], color='black')
slope, b =np.polyfit(x, land_REGEN_month_eof2['pc'], deg=1)
ax.set_title('S-VAR RawAnomaly EOF2')
ax.legend()

# ax = axes.flatten()[11]
ax = fig.add_subplot(gs[4, 2])
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(land_GPCP_month_stand['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=land_GPCP_month_stand['pc'])
plot_pc(land_MSWEP_month_stand['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=land_MSWEP_month_stand['pc'])
plot_pc(land_REGEN_month_stand['obs_pc'], color=REGEN_color, label='REGEN', ax=ax, ref=land_MSWEP_month_stand['pc'])
ax.plot(x, land_MSWEP_month_stand['pc'], color='black')
slope, b =np.polyfit(x, land_MSWEP_month_stand['pc'], deg=1)
ax.set_title('S-VAR StdAnomaly EOF1')
ax.legend()


plt.tight_layout()
plt.annotate('a)', xy=(0.05, .99), xycoords='figure fraction', fontsize=12, weight='bold')
plt.annotate('b)', xy=(0.05, .47), xycoords='figure fraction', fontsize=12, weight='bold')
# plt.annotate('SST', xy=(0., 0.15), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
# plt.annotate('monmaxpr', xy=(0., 0.46), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
# plt.annotate('monpr', xy=(0, 0.78), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
plt.savefig('Pr-PC.png', bbox_inches='tight', dpi=150)
plt.show()

# %%
len(land_MSWEP_month_stand['obs_pc'])

# %%
len(land_MSWEP_month_stand['pc'])

# %%
len(land_GPCP_eof2['pc'])

# %%
colors = sns.color_palette('deep', 6)
GPCP_color = colors[2]
MSWEP_color = colors[-2]
REGEN_color = colors[-1]
x = np.arange(len(metrics_GPCP['sn']))
time = metrics_GPCP['obs_pc'].time[12:]
x_ticks = np.arange(40, 852, 200)
start_month = np.datetime64('1984-01')
tick_time = [start_month+np.timedelta64(i,'M') for i in x_ticks]
def plot_sn(data, color, label, ax, ref):
    x = np.arange(len(data))
    # r, p = pearsonr(data, ref)
    ax.plot(x, data, label=label, color=color)

def ax_add(ax):
    ax.axhline(2, color='black')
    ax.set_xticks(x_ticks)
    ax.set_xticklabels(tick_time)  

#fig, axes = plt.subplots(nrows=4, ncols=3, sharey=False, sharex='row', figsize=(8, 10))
fig = plt.figure(figsize=(8, 10))
gs = GridSpec(figure=fig, nrows=5, ncols=3, height_ratios=[1, 1, .01, 1, 1])
ax = fig.add_subplot(gs[0, 0])
ax_add(ax)
plot_sn(metrics_GPCP['sn_obs'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP['sn'])
plot_sn(metrics_MSWEP['sn_obs'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP['sn'])
ax.plot(x, metrics_GPCP['sn'], color='black')
slope, b =np.polyfit(x, metrics_GPCP['sn'], deg=1)
ax.set_title('S-INV RawAnomaly EOF1')
ax.legend()

ax = fig.add_subplot(gs[0, 1])
ax_add(ax)
plot_sn(metrics_GPCP_eof2['sn_obs'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_eof2['sn'])
plot_sn(metrics_MSWEP_eof2['sn_obs'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_eof2['sn'])
ax.plot(x, metrics_GPCP_eof2['sn'], color='black')
slope, b =np.polyfit(x, metrics_GPCP['sn'], deg=1)
ax.set_title('S-INV RawAnomaly EOF2')
ax.legend()

ax = fig.add_subplot(gs[0, 2])
ax_add(ax)
plot_sn(metrics_GPCP_stand['sn_obs'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_stand['sn'])
plot_sn(metrics_MSWEP_stand['sn_obs'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_stand['sn'])
ax.plot(x, metrics_GPCP_stand['sn'], color='black')
slope, b =np.polyfit(x, metrics_GPCP_stand['sn'], deg=1)
ax.set_title('S-INV StdAnomaly EOF1')
ax.legend()

ax = fig.add_subplot(gs[1, 0])
ax_add(ax)
plot_sn(metrics_GPCP_month['sn_obs'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_month['sn'])
plot_sn(metrics_MSWEP_month['sn_obs'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_month['sn'])
ax.plot(x, metrics_GPCP_month['sn'], color='black')
slope, b =np.polyfit(x, metrics_GPCP_month['sn'], deg=1)
ax.set_title('S-VAR RawAnomaly EOF1')
ax.legend()

ax = fig.add_subplot(gs[1, 1])
ax_add(ax)
plot_sn(metrics_GPCP_month_eof2['sn_obs'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_month_eof2['sn'])
plot_sn(metrics_MSWEP_month_eof2['sn_obs'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_month_eof2['sn'])
ax.plot(x, metrics_GPCP_month_eof2['sn'], color='black')
slope, b =np.polyfit(x, metrics_GPCP_month['sn'], deg=1)
ax.set_title('S-VAR RawAnomaly EOF2')
ax.legend()

ax = fig.add_subplot(gs[1, 2])
ax_add(ax)
plot_sn(metrics_GPCP_month_stand['sn_obs'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_month_stand['sn'])
plot_sn(metrics_MSWEP_month_stand['sn_obs'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_month_stand['sn'])
ax.plot(x, metrics_GPCP_month_stand['sn'], color='black')
slope, b =np.polyfit(x, metrics_GPCP_month_stand['sn'], deg=1)
ax.set_title('S-VAR StdAnomaly EOF1')
ax.legend()

# land
x = np.arange(len(land_MSWEP_month_stand['sn']))
time = land_MSWEP_month_stand['obs_pc'].time[12:]
x_ticks = np.arange(40, 852, 180)
start_month = np.datetime64('1984-01')
tick_time = [start_month+np.timedelta64(i,'M') for i in x_ticks]
ax = fig.add_subplot(gs[3, 0])
ax_add(ax)
plot_sn(land_GPCP['sn_obs'], color=GPCP_color, label='GPCP', ax=ax, ref=land_MSWEP['sn'])
plot_sn(land_MSWEP['sn_obs'], color=MSWEP_color, label='MSWEP', ax=ax, ref=land_MSWEP['sn'])
plot_sn(land_REGEN['sn_obs'], color=REGEN_color, label='REGEN', ax=ax, ref=land_MSWEP['sn'])
ax.plot(x, land_MSWEP['sn'], color='black')
slope, b =np.polyfit(x, land_MSWEP['sn'], deg=1)
ax.set_title('S-INV RawAnomaly EOF1')
ax.legend()

ax = fig.add_subplot(gs[3, 1])
ax_add(ax)
plot_sn(land_GPCP_eof2['sn_obs'], color=GPCP_color, label='GPCP', ax=ax, ref=land_GPCP_eof2['sn'])
plot_sn(land_MSWEP_eof2['sn_obs'], color=MSWEP_color, label='MSWEP', ax=ax, ref=land_GPCP_eof2['sn'])
plot_sn(land_REGEN_eof2['sn_obs'], color=REGEN_color, label='REGEN', ax=ax, ref=land_REGEN_eof2['sn'])
ax.plot(x, land_REGEN_eof2['sn'], color='black')
slope, b =np.polyfit(x, land_REGEN_eof2['sn'], deg=1)
ax.set_title('S-INV RawAnomaly EOF2')
ax.legend()


ax = fig.add_subplot(gs[3, 2])
ax_add(ax)
plot_sn(land_GPCP_stand['sn_obs'], color=GPCP_color, label='GPCP', ax=ax, ref=land_GPCP_stand['sn'])
plot_sn(land_MSWEP_stand['sn_obs'], color=MSWEP_color, label='MSWEP', ax=ax, ref=land_MSWEP_stand['sn'])
plot_sn(land_REGEN_stand['sn_obs'], color=REGEN_color, label='REGEN', ax=ax, ref=land_REGEN_stand['sn'])
ax.plot(x, land_MSWEP_stand['sn'], color='black')
slope, b =np.polyfit(x, land_MSWEP_stand['sn'], deg=1)
ax.set_title('S-INV StdAnomaly EOF1')
ax.legend()

ax = fig.add_subplot(gs[4, 0])
ax_add(ax)
plot_sn(land_GPCP_month_eof2['sn_obs'], color=GPCP_color, label='GPCP', ax=ax, ref=land_MSWEP_month_eof2['sn'])
plot_sn(land_MSWEP_month_eof2['sn_obs'], color=MSWEP_color, label='MSWEP', ax=ax, ref=land_MSWEP_month_eof2['sn'])
plot_sn(land_REGEN_month['sn_obs'], color=REGEN_color, label='REGEN', ax=ax, ref=land_REGEN_month['sn'])
ax.plot(x, land_REGEN_month['sn'], color='black')
slope, b =np.polyfit(x, land_REGEN_month['sn'], deg=1)
ax.set_title('S-VAR RawAnomaly EOF1')
ax.legend()

ax = fig.add_subplot(gs[4, 1])
ax_add(ax)
plot_sn(land_GPCP_month_eof2['sn_obs'], color=GPCP_color, label='GPCP', ax=ax, ref=land_MSWEP_month_eof2['sn'])
plot_sn(land_MSWEP_month_eof2['sn_obs'], color=MSWEP_color, label='MSWEP', ax=ax, ref=land_MSWEP_month_eof2['sn'])
plot_sn(land_REGEN_month_eof2['sn_obs'], color=REGEN_color, label='REGEN', ax=ax, ref=land_REGEN_month_eof2['sn'])
ax.plot(x, land_REGEN_month_eof2['sn'], color='black')
slope, b =np.polyfit(x, land_REGEN_month_eof2['sn'], deg=1)
ax.set_title('S-VAR RawAnomaly EOF2')
ax.legend()

ax = fig.add_subplot(gs[4, 2])
ax_add(ax)
plot_sn(land_GPCP_month_stand['sn_obs'], color=GPCP_color, label='GPCP', ax=ax, ref=land_GPCP_month_stand['sn'])
plot_sn(land_MSWEP_month_stand['sn_obs'], color=MSWEP_color, label='MSWEP', ax=ax, ref=land_MSWEP_month_stand['sn'])
plot_sn(land_REGEN_month_stand['sn_obs'], color=REGEN_color, label='REGEN', ax=ax, ref=land_MSWEP_month_stand['sn'])
ax.plot(x, land_MSWEP_month_stand['sn'], color='black')
slope, b =np.polyfit(x, land_MSWEP_month_stand['sn'], deg=1)
ax.set_title('S-VAR StdAnomaly EOF1')
ax.legend()


plt.tight_layout()
plt.annotate('a)', xy=(0.05, .99), xycoords='figure fraction', fontsize=12, weight='bold')
plt.annotate('b)', xy=(0.05, .47), xycoords='figure fraction', fontsize=12, weight='bold')
# plt.annotate('SST', xy=(0., 0.15), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
# plt.annotate('monmaxpr', xy=(0., 0.46), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
# plt.annotate('monpr', xy=(0, 0.78), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
plt.savefig('Pr-SN.png', bbox_inches='tight', dpi=150)
plt.show()

# %%
metrics_GPCP.keys()
