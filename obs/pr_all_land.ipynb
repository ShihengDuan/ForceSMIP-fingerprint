# %%
import time as clocktime
import glob
import xcdat as xc
import xarray as xr
import numpy as np
import os
import pickle

# principal component analysis
from eofs.xarray import Eof

from matplotlib import pyplot as plt
import cartopy
from matplotlib import colors
import matplotlib as mpl
from scipy.stats import norm
import seaborn as sns
from matplotlib.gridspec import GridSpec
mpl.rc('font', family='DejaVu Serif') 
# mpl.rc('font', serif='Helvetica Neue')

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-False-month-True-unforced-False-joint-False-REGEN-mask', 'rb') as pfile:
    metrics_mswep_month = pickle.load(pfile)
print(metrics_mswep_month.keys())
print(len(metrics_mswep_month['n_list']))
n_list_month = metrics_mswep_month['n_list']
print((2017-1983)*12)
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-True-unforced-False-joint-False-REGEN-mask', 'rb') as pfile:
    metrics_mswep_month_stand = pickle.load(pfile)
print(len(metrics_mswep_month_stand['n_list']))
# n_list_month = metrics_mswep_month['n_list']

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-True-unforced-True-joint-False-REGEN-mask', 'rb') as pfile:
    metrics_mswep_month_unforced = pickle.load(pfile)
print(len(metrics_mswep_month_unforced['n_list']))
# n_list_month = metrics_mswep_month['n_list']
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-False-month-False-unforced-False-joint-False-REGEN-mask', 'rb') as pfile:
    metrics_mswep = pickle.load(pfile)
print(len(metrics_mswep['n_list']))

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-False-unforced-False-joint-False-REGEN-mask', 'rb') as pfile:
    metrics_mswep_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-False-unforced-True-joint-False-REGEN-mask', 'rb') as pfile:
    metrics_mswep_unforced = pickle.load(pfile)
print(len(metrics_mswep_unforced['n_list']))
# n_list_month = metrics_mswep_month['n_list']
print((2019-1983)*12)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-True-unforced-True-joint-False-REGEN-mask', 'rb') as pfile:
    metrics_gpcp_month_unforced = pickle.load(pfile)
print(len(metrics_gpcp_month_unforced['n_list']))
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-True-unforced-False-joint-False-REGEN-mask', 'rb') as pfile:
    metrics_gpcp_month_stand = pickle.load(pfile)
print(len(metrics_gpcp_month_stand['n_list']))
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-False-month-True-unforced-False-joint-False-REGEN-mask', 'rb') as pfile:
    metrics_gpcp_month = pickle.load(pfile)
print(len(metrics_gpcp_month['n_list']))
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-False-unforced-True-joint-False-REGEN-mask', 'rb') as pfile:
    metrics_gpcp_unforced = pickle.load(pfile)
print(len(metrics_gpcp_unforced['n_list']))
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-False-unforced-False-joint-False-REGEN-mask', 'rb') as pfile:
    metrics_gpcp_stand = pickle.load(pfile)
print(len(metrics_gpcp_stand['n_list']))
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-False-month-False-unforced-False-joint-False-REGEN-mask', 'rb') as pfile:
    metrics_gpcp = pickle.load(pfile)
print(len(metrics_gpcp['n_list']))

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-True-month-False-unforced-True-joint-False', 'rb') as pfile:
    metrics_regen_unforced = pickle.load(pfile)
print(len(metrics_regen_unforced['n_list']))
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-True-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_regen_stand = pickle.load(pfile)
print(len(metrics_regen_stand['n_list']))
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-False-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_regen = pickle.load(pfile)
print(len(metrics_regen['n_list']))
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-True-month-True-unforced-True-joint-False', 'rb') as pfile:
    metrics_regen_month_unforced = pickle.load(pfile)
print(len(metrics_regen_month_unforced['n_list']))
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-True-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_regen_month_stand = pickle.load(pfile)
print(len(metrics_regen_month_stand['n_list']))
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/REGEN/pr-metrics-stand-False-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_regen_month = pickle.load(pfile)
print(len(metrics_regen_month['n_list']))

# %%
def plot_ax(ax, metrics, color='tab:red', label=None):
    upper = np.array(metrics['s_obs_list'])+np.array(metrics['obs_se'])
    lower = np.array(metrics['s_obs_list'])-np.array(metrics['obs_se'])
    center = np.array(metrics['s_obs_list'])
    # ax.plot(upper/np.array(metrics['n_list']), color=color, alpha=.5)
    # ax.plot(lower/np.array(metrics['n_list']), color=color, alpha=.5)
    if label is None:
        ax.plot(metrics['sn_obs'], color=color)
    else:
        ax.plot(metrics['sn_obs'], color=color, label=label)
    ax.fill_between(x=np.arange(396), y1=upper/np.array(metrics['n_list']), y2=lower/np.array(metrics['n_list']), 
                    color=color, alpha=.2)
    ax.plot(metrics['sn'], color='black')
    ax.plot(np.arange(center.shape[0]), np.ones_like(center)*2, color='black', linestyle='--')

# %%
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(321)
ax.set_title('Month-by-month')
plot_ax(ax, metrics_mswep_month, color='tab:red', label='MSWEP')
plot_ax(ax, metrics_gpcp_month, color='tab:green', label='GPCP')
plot_ax(ax, metrics_regen_month, color='tab:brown', label='REGEN')

ax = fig.add_subplot(323)
ax.set_title('month-by-month stand')
plot_ax(ax, metrics_mswep_month_stand, color='tab:red')
plot_ax(ax, metrics_gpcp_month_stand, color='tab:green')
plot_ax(ax, metrics_regen_month_stand, color='tab:brown')
ax = fig.add_subplot(325)
ax.set_title('Month-by-month unforced')
plot_ax(ax, metrics_mswep_month_unforced, color='tab:red')
plot_ax(ax, metrics_gpcp_month_unforced, color='tab:green')
plot_ax(ax, metrics_regen_month_unforced, color='tab:brown')
ax = fig.add_subplot(322)
ax.set_title('Anomaly')
plot_ax(ax, metrics_mswep, color='tab:red')
plot_ax(ax, metrics_gpcp, color='tab:green')
plot_ax(ax, metrics_regen, color='tab:brown')
ax = fig.add_subplot(324)
ax.set_title('stand')
plot_ax(ax, metrics_mswep_stand, color='tab:red')
plot_ax(ax, metrics_gpcp_stand, color='tab:green')
plot_ax(ax, metrics_regen_stand, color='tab:brown')
ax = fig.add_subplot(326)
ax.set_title('unforced')
plot_ax(ax, metrics_mswep_unforced, color='tab:red', label='MSWEP')
plot_ax(ax, metrics_gpcp_unforced, color='tab:green', label='GPCP')
plot_ax(ax, metrics_regen_unforced, color='tab:brown', label='REGEN')
hs, ls = ax.get_legend_handles_labels()
fig.legend(hs, ls, bbox_to_anchor=(1., 1.02), bbox_transform=fig.transFigure, ncol=2)
plt.tight_layout()

# %%
path = '/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/pr-CMIP-metrics-stand-True-month-False-unforced-True-joint-False-REGEN-mask'
with open(path, 'rb') as pfile:
    cmip_unforced = pickle.load(pfile)
print(cmip_unforced.keys())

path = '/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/pr-CMIP-metrics-stand-True-month-False-unforced-False-joint-False-REGEN-mask'
with open(path, 'rb') as pfile:
    cmip_stand = pickle.load(pfile)

path = '/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/pr-CMIP-metrics-stand-False-month-False-unforced-False-joint-False-REGEN-mask'
with open(path, 'rb') as pfile:
    cmip = pickle.load(pfile)
print(cmip.keys())

# %%
path = '/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/pr-CMIP-metrics-stand-True-month-True-unforced-True-joint-False-REGEN-mask'
with open(path, 'rb') as pfile:
    cmip_month_unforced = pickle.load(pfile)
print(cmip_month_unforced.keys())

path = '/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/pr-CMIP-metrics-stand-True-month-True-unforced-False-joint-False-REGEN-mask'
with open(path, 'rb') as pfile:
    cmip_month_stand = pickle.load(pfile)

path = '/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/pr-CMIP-metrics-stand-False-month-True-unforced-False-joint-False-REGEN-mask'
with open(path, 'rb') as pfile:
    cmip_month = pickle.load(pfile)
print(cmip_month.keys())

# %%
detect_time_stand = []
for i in range(5):
    data = cmip_stand['model_results'][i]['sn']
    data = data.reindex(time=list(reversed(data.time)))
    indices = (data < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = data.time.shape[0]
    back = whole_period-first_indices
    back = back[back<whole_period]
    detect_time_stand.append(back)

detect_time_anomaly = []
for i in range(5):
    data = cmip['model_results'][i]['sn']
    data = data.reindex(time=list(reversed(data.time)))
    indices = (data < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = data.time.shape[0]
    back = whole_period-first_indices
    back = back[back<whole_period]
    detect_time_anomaly.append(back)

detect_time_unforced = []
for i in range(5):
    data = cmip_unforced['model_results'][i]['sn']
    data = data.reindex(time=list(reversed(data.time)))
    indices = (data < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = data.time.shape[0]
    back = whole_period-first_indices
    back = back[back<whole_period]
    detect_time_unforced.append(back)

# %%
detect_time_month_stand = []
for i in range(5):
    data = cmip_month_stand['model_results'][i]['sn']
    data = data.reindex(time=list(reversed(data.time)))
    indices = (data < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = data.time.shape[0]
    back = whole_period-first_indices
    back = back[back<whole_period]
    detect_time_month_stand.append(back)

detect_time_month_anomaly = []
for i in range(5):
    data = cmip_month['model_results'][i]['sn']
    data = data.reindex(time=list(reversed(data.time)))
    indices = (data < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = data.time.shape[0]
    back = whole_period-first_indices
    back = back[back<whole_period]
    detect_time_month_anomaly.append(back)

detect_time_month_unforced = []
for i in range(5):
    data = cmip_month_unforced['model_results'][i]['sn']
    data = data.reindex(time=list(reversed(data.time)))
    indices = (data < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = data.time.shape[0]
    back = whole_period-first_indices
    back = back[back<whole_period]
    detect_time_month_unforced.append(back)
time = cmip_month_unforced['model_results'][i]['sn'].time

# %%
def get_detection_obs(metrics):
    upper = np.array(metrics['s_obs_list'])+np.array(metrics['obs_se'])
    lower = np.array(metrics['s_obs_list'])-np.array(metrics['obs_se'])
    center = np.array(metrics['s_obs_list'])
    upper = upper/np.array(metrics['n_list'])
    lower = lower/np.array(metrics['n_list'])
    center = center/np.array(metrics['n_list'])
    upper = xr.DataArray(upper, dims=['time'], coords={'time': time})
    lower = xr.DataArray(lower, dims=['time'], coords={'time': time})
    center = xr.DataArray(center, dims=['time'], coords={'time': time})

    upper = upper.reindex(time=list(reversed(upper.time)))
    lower = lower.reindex(time=list(reversed(lower.time)))
    center = center.reindex(time=list(reversed(center.time)))

    indices = (upper < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = upper.time.shape[0]
    back = whole_period-first_indices
    if back<whole_period:
        detect_time_upper = back
    else:
        detect_time_upper = None
    
    indices = (lower < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = lower.time.shape[0]
    back = whole_period-first_indices
    if back<whole_period:
        detect_time_lower = back
    else:
        detect_time_lower = None

    indices = (center < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = center.time.shape[0]
    back = whole_period-first_indices
    if back<whole_period:
        detect_time_center = back
    else:
        detect_time_center = None
    return detect_time_lower, detect_time_center, detect_time_upper

# %%
root_dir = "/p/lustre3/shiduan/ForceSMIP"
files = glob.glob(root_dir + '/Training/' + 'Amon' + '/' + 'pr' + '/*')
models = [p.split('/')[-1] for p in files]
models = sorted(models)
print(models)

# %%
colors = ['tab:red', 'tab:blue', 'tab:pink', 'tab:gray', 'tab:purple']
colors = sns.color_palette('muted', 6)
print(models)
xmin = 100
xmax = 420
for i, back in enumerate(detect_time_anomaly):
    plt.hist(back, alpha=0.2, density=True, color=colors[i])
    mu, std = norm.fit(back)
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, linewidth=2, color=colors[i], label=models[i]+' n:'+str(len(back)))
plt.legend()
plt.show()
for i, back in enumerate(detect_time_stand):
    plt.hist(back, alpha=0.2, density=True, color=colors[i])
    mu, std = norm.fit(back)
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, linewidth=2, color=colors[i], label=models[i]+' n:'+str(len(back)))
plt.legend()
plt.show()
for i, back in enumerate(detect_time_unforced):
    plt.hist(back, alpha=0.2, density=True, color=colors[i])
    mu, std = norm.fit(back)
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, linewidth=2, color=colors[i], label=models[i]+' n:'+str(len(back)))
plt.legend()
plt.show()

# %%
colors = ['tab:red', 'tab:blue', 'tab:pink', 'tab:gray', 'tab:purple']
colors = sns.color_palette('deep', 3)
print(models)
xmin = 80
xmax = 420
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 8), sharex=True)

for i, back in enumerate(detect_time_month_anomaly):
    # plt.hist(back, alpha=0.2, density=True, color=colors[i])
    mu, std = norm.fit(back)
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    ax = axes.flatten()[i]
    ax.plot(x, p, linewidth=2, color=colors[0], label='Month Anomaly', linestyle='-.')

for i, back in enumerate(detect_time_month_stand):
    # plt.hist(back, alpha=0.2, density=True, color=colors[i])
    mu, std = norm.fit(back)
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    ax = axes.flatten()[i]
    ax.plot(x, p, linewidth=2, color=colors[1], label='Month Stand', linestyle='-.')

for i, back in enumerate(detect_time_month_unforced):
    # plt.hist(back, alpha=0.2, density=True, color=colors[i])
    mu, std = norm.fit(back)
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    ax = axes.flatten()[i]
    ax.plot(x, p, linewidth=2, color=colors[2], label='Month Unforced', linestyle='-.')

for i, back in enumerate(detect_time_anomaly):
    # plt.hist(back, alpha=0.2, density=True, color=colors[i])
    mu, std = norm.fit(back)
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    ax = axes.flatten()[i]
    ax2 = ax.twinx()
    ax2.plot(x, p, linewidth=2, color=colors[0], label='Anomaly')

for i, back in enumerate(detect_time_stand):
    # plt.hist(back, alpha=0.2, density=True, color=colors[i])
    mu, std = norm.fit(back)
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    ax = axes.flatten()[i]
    ax.plot(x, p, linewidth=2, color=colors[1], label='Stand')

for i, back in enumerate(detect_time_unforced):
    # plt.hist(back, alpha=0.2, density=True, color=colors[i])
    mu, std = norm.fit(back)
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    ax = axes.flatten()[i]
    ax.plot(x, p, linewidth=2, color=colors[2], label='Unforced')


for i, model in enumerate(models):
    ax = axes.flatten()[i]
    ax.set_title(model)
    # plt.legend(ncol=2)
handles, labels = ax.get_legend_handles_labels()
h, l = ax2.get_legend_handles_labels()
handles.insert(3, h[0])
labels.insert(3, l[0])
fig.legend(handles, labels, ncol=1, bbox_to_anchor=(.85, 0.5))
fig.delaxes(axes.flatten()[-1])
fig.supxlabel('Month of Detection')
fig.supylabel('Probability Density')
plt.tight_layout()
plt.show()

# %%
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics=metrics_gpcp_month)
print(detect_time_upper, detect_time_center, detect_time_lower)
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics=metrics_gpcp_month_stand)
print(detect_time_upper, detect_time_center, detect_time_lower)

# %%
len(detect_time_stand)

# %%
print(get_detection_obs(metrics=metrics_gpcp))
print(get_detection_obs(metrics=metrics_gpcp_stand))

# %% [markdown]
# # Detection time

# %%
xmin = 40
xmax = 444
x_ticks = np.arange(xmin, xmax, 180).reshape(-1)
x_ticks
start_month = np.datetime64('1983-01')
tick_time = [start_month+np.timedelta64(i,'M') for i in x_ticks]
# tick_time = time_period[40+12:420+12]
print(len(tick_time))
print(tick_time[0], ' ', tick_time[-1])
colors = sns.color_palette('deep', 8)
mswep_color = colors[-2]
gpcp_color = colors[-1]
regen_color = colors[-3]

# %%
def plot_detection_ax(ax, detect, gpcp, mswep, regen, cmip_label=False):
    xmin = 40
    xmax = 444
    for i, back in enumerate(detect):
        # plt.hist(back, alpha=0.2, density=True, color=colors[i])
        mu, std = norm.fit(back)
        x = np.linspace(xmin, xmax, 100)
        p = norm.pdf(x, mu, std)
        if cmip_label:
            ax.plot(x, p, linewidth=1, color=colors[i], label=models[i])
        else:
            ax.plot(x, p, linewidth=1, color=colors[i])
    detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics=gpcp)
    if detect_time_center is not None:
        if cmip_label:
            ax.axvline(x=detect_time_center, ymin=0, ymax=1, color=gpcp_color, linewidth=2, label='GPCP')
        else:
            ax.axvline(x=detect_time_center, ymin=0, ymax=1, color=gpcp_color, linewidth=2)
        ax.axvspan(detect_time_lower, detect_time_upper, alpha=0.2, color=gpcp_color)
        if detect_time_lower is None:
            detect_time_lower = xmax
            uncertain = None
        else:
            uncertain = detect_time_lower.data-detect_time_upper.data
        if uncertain is None:
            ax.axvspan(detect_time_lower, detect_time_upper, alpha=0.2, color=gpcp_color)
        else:
            ax.axvspan(detect_time_lower, detect_time_upper, alpha=0.2, color=gpcp_color, label='GPCP '+str(round(uncertain, 2)))

    detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics=mswep)
    if detect_time_center is not None:
        if cmip_label:
            ax.axvline(x=detect_time_center, ymin=0, ymax=1, color=mswep_color, linewidth=2, label='MSWEP')
        else:
            ax.axvline(x=detect_time_center, ymin=0, ymax=1, color=mswep_color, linewidth=2)
        if detect_time_lower is None:
            detect_time_lower = xmax
            uncertain = None
        else:
            uncertain = detect_time_lower.data-detect_time_upper.data
        if uncertain is None:
            ax.axvspan(detect_time_lower, detect_time_upper, alpha=0.2, color=mswep_color)
        else:
            ax.axvspan(detect_time_lower, detect_time_upper, alpha=0.2, color=mswep_color, label='MSWEP '+str(round(uncertain, 2)))
    detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics=regen)
    if detect_time_center is not None:
        if cmip_label:
            ax.axvline(x=detect_time_center, ymin=0, ymax=1, color=regen_color, linewidth=2, label='REGEN')
        else:
            ax.axvline(x=detect_time_center, ymin=0, ymax=1, color=regen_color, linewidth=2)
        if detect_time_lower is None:
            detect_time_lower = xmax
            uncertain = None
        else:
            uncertain = detect_time_lower.data-detect_time_upper.data
        if uncertain is None:
            ax.axvspan(detect_time_lower, detect_time_upper, alpha=0.2, color=regen_color)
        else:
            ax.axvspan(detect_time_lower, detect_time_upper, alpha=0.2, color=regen_color, label='REGEN '+str(round(uncertain, 2)))
    if cmip_label:
        hs, ls = ax.get_legend_handles_labels()
        hs = [hs[-3], hs[-1]]
        ls = [ls[-3], ls[-1]]
        ax.legend(hs, ls, loc='upper right')
    else:
        ax.legend(loc='upper right')

# %%
colors = sns.color_palette('deep', 7)
mswep_color = colors[-2]
gpcp_color = colors[-1]
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 6), sharex=True)
xmin = 40
xmax = 444
ax = axes.flatten()[0]
ax.set_title('Anomaly')
plot_detection_ax(ax, detect_time_stand, gpcp=metrics_gpcp, mswep=metrics_mswep, regen=metrics_regen)

ax = axes.flatten()[1]
ax.set_title('StdAnomaly')
plot_detection_ax(ax, detect_time_stand, gpcp=metrics_gpcp_stand, mswep=metrics_mswep_stand, regen=metrics_regen_stand)
ax = axes.flatten()[2]
ax.set_title('UnforcedAnomaly')
plot_detection_ax(ax, detect_time_unforced, gpcp=metrics_gpcp_unforced, mswep=metrics_mswep_unforced, regen=metrics_regen_unforced)

ax = axes.flatten()[3]
ax.set_title('Month Anomaly')
plot_detection_ax(ax, detect_time_month_anomaly, gpcp=metrics_gpcp_month, mswep=metrics_mswep_month, regen=metrics_regen_month)

ax = axes.flatten()[4]
ax.set_title('Month StdAnomaly')
plot_detection_ax(ax, detect_time_month_stand, gpcp=metrics_gpcp_month_stand, mswep=metrics_mswep_month_stand, regen=metrics_regen_month_stand)

ax = axes.flatten()[5]
ax.set_title('Month UnforcedAnomaly')
plot_detection_ax(ax, detect_time_month_unforced, gpcp=metrics_gpcp_month_unforced, 
                  mswep=metrics_mswep_month_unforced, regen=metrics_regen_month_unforced, cmip_label=True)

hs, ls = ax.get_legend_handles_labels()
ls.pop(-1)
ls.pop(-2)
hs.pop(-1)
hs.pop(-2)
fig.legend(hs, ls, bbox_to_anchor=(-.01, .85), bbox_transform=fig.transFigure, ncol=1)
for ax in axes.flatten()[1:]:
    ax.set_xticks(x_ticks)
    ax.set_xticklabels(tick_time)
fig.supxlabel('Detection Time')
fig.supylabel('Probability Density')
plt.tight_layout()
# plt.savefig('detection-pr.png', dpi=160, bbox_inches='tight')

# %%
ls

# %%
hs, ls = ax.get_legend_handles_labels()
print(ls)

# %% [markdown]
# # Signal/Noise

# %%
cmip_month_unforced['model_results'][i]['sn'].isel(time=-1)

# %%
cmip_month_unforced['model_results']

# %%
def ax_plot_sn(ax, cmip, gpcp, mswep, regen, cmip_label=False):
    for i in range(5):
        data = cmip['model_results'][i]
        data = data['sn'].isel(time=-1)
        mu, std = norm.fit(data)
        x = np.linspace(xmin, xmax, 100)
        p = norm.pdf(x, mu, std)
        if cmip_label:
            ax.plot(x, p, linewidth=1, color=colors[i], label=models[i])
        else:
            ax.plot(x, p, linewidth=1, color=colors[i])
    s_obs_list = gpcp['s_obs_list']
    s_se = gpcp['obs_se']
    n_list = gpcp['n_list']
    center = s_obs_list[-1]/n_list[-1]
    upper = (s_obs_list[-1]+s_se[-1])/n_list[-1]
    lower = (s_obs_list[-1]-s_se[-1])/n_list[-1]
    uncertain = upper.data-lower.data
    if cmip_label:
        ax.axvline(x=center, ymin=0, ymax=1, color=gpcp_color, linewidth=2, label='GPCP')
    else:
        ax.axvline(x=center, ymin=0, ymax=1, color=gpcp_color, linewidth=2)
    ax.axvspan(upper, lower, alpha=0.2, color=gpcp_color, label='GPCP '+str(round(uncertain, 2)))
    print(center)
    s_obs_list = mswep['s_obs_list']
    s_se = mswep['obs_se']
    n_list = mswep['n_list']
    center = s_obs_list[-1]/n_list[-1]
    upper = (s_obs_list[-1]+s_se[-1])/n_list[-1]
    lower = (s_obs_list[-1]-s_se[-1])/n_list[-1]
    uncertain = upper.data-lower.data
    if cmip_label:
        ax.axvline(x=center, ymin=0, ymax=1, color=mswep_color, linewidth=2, label='MSWEP')
    else:
        ax.axvline(x=center, ymin=0, ymax=1, color=mswep_color, linewidth=2)
    ax.axvspan(upper, lower, alpha=0.2, color=mswep_color, label='MSWEP '+str(round(uncertain, 2)))
    ax.axvline(x=2, ymin=0, ymax=1, color='black', linewidth=1, linestyle='--')
    print(center)
    
    s_obs_list = regen['s_obs_list']
    s_se = regen['obs_se']
    n_list = regen['n_list']
    center = s_obs_list[-1]/n_list[-1]
    upper = (s_obs_list[-1]+s_se[-1])/n_list[-1]
    lower = (s_obs_list[-1]-s_se[-1])/n_list[-1]
    uncertain = upper.data-lower.data
    if cmip_label:
        ax.axvline(x=center, ymin=0, ymax=1, color=regen_color, linewidth=2, label='REGEN')
    else:
        ax.axvline(x=center, ymin=0, ymax=1, color=regen_color, linewidth=2)
    ax.axvspan(upper, lower, alpha=0.2, color=regen_color, label='REGEN '+str(round(uncertain, 2)))
    ax.axvline(x=2, ymin=0, ymax=1, color='black', linewidth=1, linestyle='--')
    print(center)
    if cmip_label:
        hs, ls = ax.get_legend_handles_labels()
        hs = [hs[-5], hs[-3], hs[-1]]
        ls = [ls[-5], ls[-3], ls[-1]]
        ax.legend(hs, ls, loc='upper right')
    else:
        ax.legend(loc='upper right')
    ax.set_xticks([-2, 0, 2, 4, 6, 8, 10])

# %%
colors = sns.color_palette('deep', 8)
mswep_color = colors[-2]
gpcp_color = colors[-1]
regen_color = colors[-3]
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 6), sharex=True, sharey=True)
xmin = -2
xmax = 10
ax = axes.flatten()[0]
ax.set_title('Anomaly', fontsize=12)
ax_plot_sn(ax, cmip=cmip, gpcp=metrics_gpcp, mswep=metrics_mswep, regen=metrics_regen)

ax = axes.flatten()[1]
ax.set_title('StdAnomaly', fontsize=12)
ax_plot_sn(ax, cmip=cmip_stand, gpcp=metrics_gpcp_stand, mswep=metrics_mswep_stand, regen=metrics_regen_stand)

ax = axes.flatten()[2]
ax.set_title('UnforcedAnomaly', fontsize=12)
ax_plot_sn(ax, cmip=cmip_unforced, gpcp=metrics_gpcp_unforced, mswep=metrics_mswep_unforced, regen=metrics_regen_unforced)

ax = axes.flatten()[3]
ax.set_title('Month Anomaly', fontsize=12)
ax_plot_sn(ax, cmip=cmip_month, gpcp=metrics_gpcp_month, mswep=metrics_mswep_month, regen=metrics_regen_month)

ax = axes.flatten()[4]
ax.set_title('Month StdAnomaly', fontsize=12)
ax_plot_sn(ax, cmip=cmip_month_stand, gpcp=metrics_gpcp_month_stand, mswep=metrics_mswep_month_stand, regen=metrics_regen_month_stand)

ax = axes.flatten()[5]
ax.set_title('Month UnforcedAnomaly', fontsize=12)
ax_plot_sn(ax, cmip=cmip_month_unforced, gpcp=metrics_gpcp_month_unforced, 
           mswep=metrics_mswep_month_unforced, regen=metrics_regen_month_unforced, cmip_label=True)

ax.set_xticks([-2, 0, 2, 4, 6, 8, 10])
hs, ls = ax.get_legend_handles_labels()
ls.pop(-1)
ls.pop(-2)
ls.pop(-3)
hs.pop(-1)
hs.pop(-2)
hs.pop(-3)
fig.legend(hs, ls, bbox_to_anchor=(.85, 1.1), bbox_transform=fig.transFigure, ncol=4, fontsize=12)
fig.supylabel('Probability Density')
fig.supxlabel('S/N Ratio')
plt.tight_layout()
# plt.savefig('SNratio-pr.png', dpi=160, bbox_inches='tight')

# %%
hs, ls = ax.get_legend_handles_labels()
print(hs)
print(ls)

# %%
[ls[-3], ls[-1]]

# %%
ls.pop(-1)
ls.pop(-2)
print(ls)

# %% [markdown]
# # Combine

# %%
colors = sns.color_palette('deep', 8)
mswep_color = colors[-2]
gpcp_color = colors[-1]
regen_color = colors[-3]
fig, axes = plt.subplots(nrows=5, ncols=3, sharex='row', sharey=False,
                               gridspec_kw={'height_ratios': [10, 10, 1e-10, 10, 10]},
                               figsize=(9, 12))
'''fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(10, 10), 
                         # sharex=True, sharey=True,
                         )'''
# fig = plt.figure(figsize=(9, 12))
# gs = GridSpec(5, 3, figure=fig, height_ratios=[10, 10, 1e-10, 10, 10])
xmin = -2
xmax = 10
ax = axes.flatten()[0]
ax.set_title('AllM Anomaly', fontsize=12, fontname='DejaVu Serif')
ax_plot_sn(ax, cmip=cmip, gpcp=metrics_gpcp, mswep=metrics_mswep, regen=metrics_regen)

ax = axes.flatten()[1]
ax.set_title('AllM StdAnomaly', fontsize=12, fontname='DejaVu Serif')
ax_plot_sn(ax, cmip=cmip_stand, gpcp=metrics_gpcp_stand, mswep=metrics_mswep_stand, regen=metrics_regen_stand)

ax = axes.flatten()[2]
ax.set_title('AllM UnforcedAnomaly', fontsize=12, fontname='DejaVu Serif')
ax_plot_sn(ax, cmip=cmip_unforced, gpcp=metrics_gpcp_unforced, mswep=metrics_mswep_unforced, regen=metrics_regen_unforced)

ax = axes.flatten()[3]
ax.set_title('MbyM Anomaly', fontsize=12, fontname='DejaVu Serif')
ax_plot_sn(ax, cmip=cmip_month, gpcp=metrics_gpcp_month, mswep=metrics_mswep_month, regen=metrics_regen_month)

ax = axes.flatten()[4]
ax.set_title('MbyM StdAnomaly', fontsize=12, fontname='DejaVu Serif')
ax_plot_sn(ax, cmip=cmip_month_stand, gpcp=metrics_gpcp_month_stand, mswep=metrics_mswep_month_stand, regen=metrics_regen_month_stand)

ax = axes.flatten()[5]
ax.set_title('MbyM UnforcedAnomaly', fontsize=12, fontname='DejaVu Serif')
ax_plot_sn(ax, cmip=cmip_month_unforced, gpcp=metrics_gpcp_month_unforced, 
           mswep=metrics_mswep_month_unforced, cmip_label=True, regen=metrics_regen_month_unforced)
ax.set_xticks([-2, 0, 2, 4, 6, 8, 10])
ax.set_yticks([0, .2, .4, .6, .8])
hs, ls = ax.get_legend_handles_labels()
ls.pop(-1)
ls.pop(-2)
ls.pop(-3)
hs.pop(-1)
hs.pop(-2)
hs.pop(-3)
for i in range(6, 9):
    fig.delaxes(axes.flatten()[i])

# detection time

ax = axes.flatten()[9]
ax.set_title('AllM Anomaly', fontsize=12, fontname='DejaVu Serif')
plot_detection_ax(ax, detect_time_anomaly, gpcp=metrics_gpcp, mswep=metrics_mswep, regen=metrics_regen)

ax = axes.flatten()[10]
ax.set_title('AllM StdAnomaly', fontsize=12, fontname='DejaVu Serif')
plot_detection_ax(ax, detect_time_stand, gpcp=metrics_gpcp_stand, mswep=metrics_mswep_stand, regen=metrics_regen_stand)

ax = axes.flatten()[11]
ax.set_title('AllM UnforcedAnomaly', fontsize=12, fontname='DejaVu Serif')
plot_detection_ax(ax, detect_time_unforced, gpcp=metrics_gpcp_unforced, mswep=metrics_mswep_unforced, regen=metrics_regen_unforced)

ax = axes.flatten()[12]
ax.set_title('MbyM Anomaly', fontsize=12, fontname='DejaVu Serif')
plot_detection_ax(ax, detect_time_month_anomaly, gpcp=metrics_gpcp_month, mswep=metrics_mswep_month, regen=metrics_regen_month)

ax = axes.flatten()[13]
ax.set_title('MbyM stdAnomaly', fontsize=12, fontname='DejaVu Serif')
plot_detection_ax(ax, detect_time_month_stand, gpcp=metrics_gpcp_month_stand, mswep=metrics_mswep_month_stand, regen=metrics_regen_month_stand)

ax = axes.flatten()[14]
ax.set_title('MbyM UnforcedAnomaly', fontsize=12, fontname='DejaVu Serif')
plot_detection_ax(ax, detect_time_month_unforced, gpcp=metrics_gpcp_month_unforced, 
                  mswep=metrics_mswep_month_unforced, regen=metrics_regen_month_unforced, cmip_label=True)


fig.legend(hs, ls, bbox_to_anchor=(.9, 1.06), bbox_transform=fig.transFigure, ncol=4, fontsize=12)
fig.supylabel('Probability Density')
plt.tight_layout()
plt.annotate('SNR', xy=(.5, .52), xycoords='figure fraction', fontsize=12)
plt.annotate('ToE', xy=(.5, .001), xycoords='figure fraction', fontsize=12)
for ax in axes.flatten()[10:]:
    ax.set_xticks(x_ticks)
    ax.set_xticklabels(tick_time)
    ax.set_yticks([0, 0.004, 0.008, 0.012])
    ax.set_yticklabels([0, 0.004, 0.008, 0.012])

plt.savefig('Figure-pr-land.png', dpi=160, bbox_inches='tight')
plt.show()
