# %%
import xarray as xa
import pickle
from matplotlib import pyplot as plt
import numpy as np
from scipy.stats import pearsonr
import seaborn as sns
import matplotlib as mpl
mpl.rc('font', family='DejaVu Serif')

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-False-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_GPCP_month = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_GPCP_month_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-True-unforced-True-joint-False', 'rb') as pfile:
    metrics_GPCP_month_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-False-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_GPCP = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_GPCP_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/GPCP/pr-metrics-stand-True-month-False-unforced-True-joint-False', 'rb') as pfile:
    metrics_GPCP_unforced = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-False-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_MSWEP_month = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_MSWEP_month_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-True-unforced-True-joint-False', 'rb') as pfile:
    metrics_MSWEP_month_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-False-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_MSWEP = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_MSWEP_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/pr-metrics-stand-True-month-False-unforced-True-joint-False', 'rb') as pfile:
    metrics_MSWEP_unforced = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/monmaxpr-metrics-stand-False-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_MSWEP_monmaxpr_month = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/monmaxpr-metrics-stand-True-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_MSWEP_monmaxpr_month_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/monmaxpr-metrics-stand-True-month-True-unforced-True-joint-False', 'rb') as pfile:
    metrics_MSWEP_monmaxpr_month_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/monmaxpr-metrics-stand-False-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_MSWEP_monmaxpr = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/monmaxpr-metrics-stand-True-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_MSWEP_monmaxpr_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1979_2022/MSWEP/monmaxpr-metrics-stand-True-month-False-unforced-True-joint-False', 'rb') as pfile:
    metrics_MSWEP_monmaxpr_unforced = pickle.load(pfile)

# %%
x = np.arange(len(metrics_GPCP_month['obs_pc']))
y = metrics_GPCP_month['pc']
y1 = metrics_GPCP_month['obs_pc']
r, p = pearsonr(y, y1)
plt.plot(x, y1, label='GPCP '+str(round(r, 2)))

plt.plot(x, y, label='CMIP6')
plt.legend()
plt.show()

# %%
def get_detection_time(data):# sn
    data = xa.DataArray(data, dims=['time'], coords={'time': np.arange(len(data))})
    data = data.reindex(time=list(reversed(data.time)))
    indices = (data < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = data.time.shape[0]
    back = whole_period-first_indices
    return back.data

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-False-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_ersst_month = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_ersst_month_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-True-unforced-True-joint-False', 'rb') as pfile:
    metrics_ersst_month_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-False-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_ersst = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_ersst_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-False-unforced-True-joint-False', 'rb') as pfile:
    metrics_ersst_unforced = pickle.load(pfile)
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-False-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_pcmdi_month = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_pcmdi_month_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-True-unforced-True-joint-False', 'rb') as pfile:
    metrics_pcmdi_month_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-False-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_pcmdi = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_pcmdi_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-False-unforced-True-joint-False', 'rb') as pfile:
    metrics_pcmdi_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-False-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_cobe_month = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_cobe_month_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-True-unforced-True-joint-False', 'rb') as pfile:
    metrics_cobe_month_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-False-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_cobe = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_cobe_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-False-unforced-True-joint-False', 'rb') as pfile:
    metrics_cobe_unforced = pickle.load(pfile)

# %% [markdown]
# # PC

# %%
colors = sns.color_palette('deep', 6)
GPCP_color = colors[2]
MSWEP_color = colors[-2]
x = np.arange(len(metrics_GPCP['pc']))
time = metrics_GPCP['pc'].time[:]
x_ticks = np.arange(40, 852, 200)
start_month = np.datetime64('1983-01')
tick_time = [start_month+np.timedelta64(i,'M') for i in x_ticks]
def plot_pc(data, color, label, ax, ref):
    x = np.arange(len(data))
    r, p = pearsonr(data, ref)
    ax.plot(x, data, label=label+' '+str(round(r, 2)), color=color)
    

fig, axes = plt.subplots(nrows=3, ncols=6, sharey=False, sharex='row', figsize=(18, 8))
ax = axes.flatten()[0]
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(metrics_GPCP['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP['pc'])
plot_pc(metrics_MSWEP['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP['pc'])
ax.plot(x, metrics_GPCP['pc'], color='black')
slope, b =np.polyfit(x, metrics_GPCP['pc'], deg=1)
ax.set_title('AllM-Anomaly')
ax.legend()
ax = axes.flatten()[1]
plot_pc(metrics_GPCP_stand['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_stand['pc'])
plot_pc(metrics_MSWEP_stand['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_stand['pc'])
ax.plot(x, metrics_GPCP_stand['pc'], color='black')
slope, b =np.polyfit(x, metrics_GPCP_stand['pc'], deg=1)
ax.set_title('AllM-StdAnomaly')
ax.legend()
ax = axes.flatten()[2]
plot_pc(metrics_GPCP_unforced['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_unforced['pc'])
plot_pc(metrics_MSWEP_unforced['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_unforced['pc'])
ax.plot(x, metrics_GPCP_unforced['pc'], color='black')
slope, b =np.polyfit(x, metrics_GPCP_unforced['pc'], deg=1)
ax.set_title('AllM-UnforcedAnomaly')
ax.legend()
ax = axes.flatten()[3]
plot_pc(metrics_GPCP_month['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_month['pc'])
plot_pc(metrics_MSWEP_month['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_month['pc'])
ax.plot(x, metrics_GPCP_month['pc'], color='black')
slope, b =np.polyfit(x, metrics_GPCP_month['pc'], deg=1)
ax.set_title('MbyM-Anomaly')
ax.legend()
ax = axes.flatten()[4]
plot_pc(metrics_GPCP_month_stand['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_month_stand['pc'])
plot_pc(metrics_MSWEP_month_stand['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_month_stand['pc'])
ax.plot(x, metrics_GPCP_month_stand['pc'], color='black')
slope, b =np.polyfit(x, metrics_GPCP_month_stand['pc'], deg=1)
ax.set_title('MbyM-StdAnomaly')
ax.legend()
ax = axes.flatten()[5]
plot_pc(metrics_GPCP_month_unforced['obs_pc'], color=GPCP_color, label='GPCP', ax=ax, ref=metrics_GPCP_month_unforced['pc'])
plot_pc(metrics_MSWEP_month_unforced['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_GPCP_month_unforced['pc'])
ax.plot(x, metrics_GPCP_month_unforced['pc'], color='black')
slope, b =np.polyfit(x, metrics_GPCP_month_unforced['pc'], deg=1)
ax.set_title('MbyM-UnforcedAnomaly')
ax.legend()
# Monmaxpr
x = np.arange(len(metrics_MSWEP_monmaxpr['pc']))
time = metrics_GPCP['pc'].time[:]
x_ticks = np.arange(40, 852, 200)
start_month = np.datetime64('1980-01')
tick_time = [start_month+np.timedelta64(i,'M') for i in x_ticks]
ax = axes.flatten()[6]
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(metrics_MSWEP_monmaxpr['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_MSWEP_monmaxpr['pc'])
ax.plot(x, metrics_MSWEP_monmaxpr['pc'], color='black')
ax.legend()
ax = axes.flatten()[7]
plot_pc(metrics_MSWEP_monmaxpr_stand['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_MSWEP_monmaxpr_stand['pc'])
ax.plot(x, metrics_MSWEP_monmaxpr_stand['pc'], color='black')
ax.legend()
ax = axes.flatten()[8]
plot_pc(metrics_MSWEP_monmaxpr_unforced['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_MSWEP_monmaxpr_unforced['pc'])
ax.plot(x, metrics_MSWEP_monmaxpr_unforced['pc'], color='black')
ax.legend()
ax = axes.flatten()[9]
plot_pc(metrics_MSWEP_monmaxpr_month['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_MSWEP_monmaxpr_month['pc'])
ax.plot(x, metrics_MSWEP_monmaxpr_month['pc'], color='black')
ax.legend()
ax = axes.flatten()[10]
plot_pc(metrics_MSWEP_monmaxpr_month_stand['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_MSWEP_monmaxpr_month_stand['pc'])
ax.plot(x, metrics_MSWEP_monmaxpr_month_stand['pc'], color='black')
ax.legend()
ax = axes.flatten()[11]
plot_pc(metrics_MSWEP_monmaxpr_month_unforced['obs_pc'], color=MSWEP_color, label='MSWEP', ax=ax, ref=metrics_MSWEP_monmaxpr_month_unforced['pc'])
ax.plot(x, metrics_MSWEP_monmaxpr_month_unforced['pc'], color='black')
ax.legend()
# SST
cobe_color = colors[-2]
pcmdi_color = colors[-1]
ersst_color = colors[-3]
x = np.arange(len(metrics_pcmdi['pc']))
time = metrics_GPCP['pc'].time[:]
x_ticks = np.arange(40, 864, 390)
start_month = np.datetime64('1950-01')
tick_time = [start_month+np.timedelta64(i,'M') for i in x_ticks]
ax = axes.flatten()[12]
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
plot_pc(metrics_pcmdi['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi['pc'])
plot_pc(metrics_cobe['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi['pc'])
plot_pc(metrics_ersst['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi['pc'])
ax.plot(x, metrics_pcmdi['pc'], color='black')
ax.legend()
ax = axes.flatten()[13]
plot_pc(metrics_pcmdi_stand['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_stand['pc'])
plot_pc(metrics_cobe_stand['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_stand['pc'])
plot_pc(metrics_ersst_stand['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_stand['pc'])
ax.plot(x, metrics_pcmdi_stand['pc'], color='black')
ax.legend()
ax = axes.flatten()[14]
plot_pc(metrics_pcmdi_unforced['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_unforced['pc'])
plot_pc(metrics_cobe_unforced['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_unforced['pc'])
plot_pc(metrics_ersst_unforced['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_unforced['pc'])
ax.plot(x, metrics_pcmdi_unforced['pc'], color='black')
ax.legend()
ax = axes.flatten()[15]
plot_pc(metrics_pcmdi_month['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_month['pc'])
plot_pc(metrics_cobe_month['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_month['pc'])
plot_pc(metrics_ersst_month['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_month['pc'])
ax.plot(x, metrics_pcmdi_month['pc'], color='black')
ax.legend()
ax = axes.flatten()[16]
plot_pc(metrics_pcmdi_month_stand['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_month_stand['pc'])
plot_pc(metrics_cobe_month_stand['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_month_stand['pc'])
plot_pc(metrics_ersst_month_stand['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_month_stand['pc'])
ax.plot(x, metrics_pcmdi_month_stand['pc'], color='black')
ax.legend()
ax = axes.flatten()[17]
plot_pc(metrics_pcmdi_month_unforced['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_month_unforced['pc'])
plot_pc(metrics_cobe_month_unforced['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_month_unforced['pc'])
plot_pc(metrics_ersst_month_unforced['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_month_unforced['pc'])
ax.plot(x, metrics_pcmdi_month_unforced['pc'], color='black')
ax.legend()
plt.tight_layout()
plt.annotate('SST', xy=(0., 0.15), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
plt.annotate('monmaxpr', xy=(0., 0.46), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
plt.annotate('monpr', xy=(0, 0.78), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
plt.savefig('PC-all.png', bbox_inches='tight', dpi=130)
plt.show()

# %% [markdown]
# # Month for AllM

# %%
metrics_GPCP.keys()

# %%
fig = plt.figure(figsize=(12, 5))
slope1 = []
slope2 = []
slope3 = []
slope4 = []
slope5 = []
slope6 = []
for i in range(1, 13):
    pc = metrics_GPCP['pc']
    pc = pc.sel(time=pc.time.dt.month==i)
    x = np.arange(pc.shape[0])
    slope, m = np.polyfit(x, pc, deg=1)
    slope1.append(slope)
    pc = metrics_GPCP_stand['pc']
    pc = pc.sel(time=pc.time.dt.month==i)
    x = np.arange(pc.shape[0])
    slope, m = np.polyfit(x, pc, deg=1)
    slope2.append(slope)
    pc = metrics_GPCP_unforced['pc']
    pc = pc.sel(time=pc.time.dt.month==i)
    x = np.arange(pc.shape[0])
    slope, m = np.polyfit(x, pc, deg=1)
    slope3.append(slope)
    
    pc = metrics_GPCP_month['pc']
    pc = pc.sel(time=pc.time.dt.month==i)
    x = np.arange(pc.shape[0])
    slope, m = np.polyfit(x, pc, deg=1)
    slope4.append(slope)
    
    pc = metrics_GPCP_month_stand['pc']
    pc = pc.sel(time=pc.time.dt.month==i)
    x = np.arange(pc.shape[0])
    slope, m = np.polyfit(x, pc, deg=1)
    slope5.append(slope)
    
    pc = metrics_GPCP_month_unforced['pc']
    pc = pc.sel(time=pc.time.dt.month==i)
    x = np.arange(pc.shape[0])
    slope, m = np.polyfit(x, pc, deg=1)
    slope6.append(slope)
    
plt.boxplot(slope1, positions=[0])
plt.boxplot(slope2, positions=[2])
plt.boxplot(slope3, positions=[4])
plt.boxplot(slope4, positions=[6])
plt.boxplot(slope5, positions=[8])
plt.boxplot(slope6, positions=[10])
plt.hlines(y=0, xmin=-0.5, xmax=10.5, color='black', linestyles='-.')
plt.show()

# %%
fig = plt.figure(figsize=(12, 5))
slope1 = []
slope2 = []
slope3 = []
slope4 = []
slope5 = []
slope6 = []
for i in range(1, 13):
    pc = metrics_MSWEP_monmaxpr['pc']
    pc = pc.sel(time=pc.time.dt.month==i)
    x = np.arange(pc.shape[0])
    slope, m = np.polyfit(x, pc, deg=1)
    slope1.append(slope)
    pc = metrics_MSWEP_monmaxpr_stand['pc']
    pc = pc.sel(time=pc.time.dt.month==i)
    x = np.arange(pc.shape[0])
    slope, m = np.polyfit(x, pc, deg=1)
    slope2.append(slope)
    pc = metrics_MSWEP_monmaxpr_unforced['pc']
    pc = pc.sel(time=pc.time.dt.month==i)
    x = np.arange(pc.shape[0])
    slope, m = np.polyfit(x, pc, deg=1)
    slope3.append(slope)
    
    pc = metrics_MSWEP_monmaxpr_month['pc']
    pc = pc.sel(time=pc.time.dt.month==i)
    x = np.arange(pc.shape[0])
    slope, m = np.polyfit(x, pc, deg=1)
    slope4.append(slope)
    
    pc = metrics_MSWEP_monmaxpr_month_stand['pc']
    pc = pc.sel(time=pc.time.dt.month==i)
    x = np.arange(pc.shape[0])
    slope, m = np.polyfit(x, pc, deg=1)
    slope5.append(slope)
    
    pc = metrics_MSWEP_monmaxpr_month_unforced['pc']
    pc = pc.sel(time=pc.time.dt.month==i)
    x = np.arange(pc.shape[0])
    slope, m = np.polyfit(x, pc, deg=1)
    slope6.append(slope)
    
plt.boxplot(slope1, positions=[0])
plt.boxplot(slope2, positions=[2])
plt.boxplot(slope3, positions=[4])
plt.boxplot(slope4, positions=[6])
plt.boxplot(slope5, positions=[8])
plt.boxplot(slope6, positions=[10])
plt.hlines(y=0, xmin=-0.5, xmax=10.5, color='black', linestyles='-.')
plt.show()
