# %%
import xarray as xa
import pickle
from matplotlib import pyplot as plt
import numpy as np
from scipy.stats import pearsonr
import seaborn as sns
import matplotlib as mpl
mpl.rc('font', family='DejaVu Serif')

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-False-month-True-unforced-False-joint-False-Pacific', 'rb') as pfile:
    metrics_cobe_month_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-True-unforced-False-joint-False-Pacific', 'rb') as pfile:
    metrics_cobe_month_stand_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-True-unforced-True-joint-False-Pacific', 'rb') as pfile:
    metrics_cobe_month_unforced_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-False-month-False-unforced-False-joint-False-Pacific', 'rb') as pfile:
    metrics_cobe_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-False-unforced-False-joint-False-Pacific', 'rb') as pfile:
    metrics_cobe_stand_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-False-unforced-True-joint-False-Pacific', 'rb') as pfile:
    metrics_cobe_unforced_pacific = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-False-month-True-unforced-False-joint-False-Pacific', 'rb') as pfile:
    metrics_pcmdi_month_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-True-unforced-False-joint-False-Pacific', 'rb') as pfile:
    metrics_pcmdi_month_stand_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-True-unforced-True-joint-False-Pacific', 'rb') as pfile:
    metrics_pcmdi_month_unforced_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-False-month-False-unforced-False-joint-False-Pacific', 'rb') as pfile:
    metrics_pcmdi_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-False-unforced-False-joint-False-Pacific', 'rb') as pfile:
    metrics_pcmdi_stand_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-False-unforced-True-joint-False-Pacific', 'rb') as pfile:
    metrics_pcmdi_unforced_pacific = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-False-month-True-unforced-False-joint-False-Pacific', 'rb') as pfile:
    metrics_ersst_month_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-True-unforced-False-joint-False-Pacific', 'rb') as pfile:
    metrics_ersst_month_stand_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-True-unforced-True-joint-False-Pacific', 'rb') as pfile:
    metrics_ersst_month_unforced_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-False-month-False-unforced-False-joint-False-Pacific', 'rb') as pfile:
    metrics_ersst_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-False-unforced-False-joint-False-Pacific', 'rb') as pfile:
    metrics_ersst_stand_pacific = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-False-unforced-True-joint-False-Pacific', 'rb') as pfile:
    metrics_ersst_unforced_pacific = pickle.load(pfile)

# %%
metrics_ersst_month_pacific.keys()

# %%
x = np.arange(len(metrics_pcmdi_month_pacific['obs_pc']))
y = metrics_pcmdi_month_pacific['pc']
y1 = metrics_pcmdi_month_pacific['obs_pc']
y2 = metrics_cobe_month_pacific['obs_pc']
y3 = metrics_ersst_month_pacific['obs_pc']
r, p = pearsonr(y, y1)
plt.plot(x, y1, label='PCMDI '+str(round(r, 2)))
r, p = pearsonr(y, y2)
plt.plot(x, y2, label='COBE '+str(round(r, 2)))
r, p = pearsonr(y, y3)
plt.plot(x, y3, label='ERSST '+str(round(r, 2)))
plt.plot(x, y, label='CMIP6')
plt.legend()
plt.show()

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-False-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_cobe_month = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_cobe_month_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-True-unforced-True-joint-False', 'rb') as pfile:
    metrics_cobe_month_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-False-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_cobe = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_cobe_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-False-unforced-True-joint-False', 'rb') as pfile:
    metrics_cobe_unforced = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-False-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_pcmdi_month = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_pcmdi_month_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-True-unforced-True-joint-False', 'rb') as pfile:
    metrics_pcmdi_month_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-False-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_pcmdi = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_pcmdi_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-False-unforced-True-joint-False', 'rb') as pfile:
    metrics_pcmdi_unforced = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-False-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_ersst_month = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-True-unforced-False-joint-False', 'rb') as pfile:
    metrics_ersst_month_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-True-unforced-True-joint-False', 'rb') as pfile:
    metrics_ersst_month_unforced = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-False-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_ersst = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-False-unforced-False-joint-False', 'rb') as pfile:
    metrics_ersst_stand = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-False-unforced-True-joint-False', 'rb') as pfile:
    metrics_ersst_unforced = pickle.load(pfile)

# %%
x = np.arange(len(metrics_pcmdi_month['obs_pc']))
y = metrics_pcmdi_month['pc']
y1 = metrics_pcmdi_month['obs_pc']
y2 = metrics_cobe_month['obs_pc']
y3 = metrics_ersst_month['obs_pc']
r, p = pearsonr(y, y1)
plt.plot(x, y1, label='PCMDI '+str(round(r, 2)))
r, p = pearsonr(y, y2)
plt.plot(x, y2, label='COBE '+str(round(r, 2)))
r, p = pearsonr(y, y3)
plt.plot(x, y3, label='ERSST '+str(round(r, 2)))
plt.plot(x, y, label='CMIP6')
plt.legend()
plt.show()

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-False-month-True-unforced-False-joint-False-Atlantic', 'rb') as pfile:
    metrics_cobe_month_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-True-unforced-False-joint-False-Atlantic', 'rb') as pfile:
    metrics_cobe_month_stand_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-True-unforced-True-joint-False-Atlantic', 'rb') as pfile:
    metrics_cobe_month_unforced_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-False-month-False-unforced-False-joint-False-Atlantic', 'rb') as pfile:
    metrics_cobe_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-False-unforced-False-joint-False-Atlantic', 'rb') as pfile:
    metrics_cobe_stand_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/COBE/tos-metrics-stand-True-month-False-unforced-True-joint-False-Atlantic', 'rb') as pfile:
    metrics_cobe_unforced_atlantic = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-False-month-True-unforced-False-joint-False-Atlantic', 'rb') as pfile:
    metrics_pcmdi_month_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-True-unforced-False-joint-False-Atlantic', 'rb') as pfile:
    metrics_pcmdi_month_stand_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-True-unforced-True-joint-False-Atlantic', 'rb') as pfile:
    metrics_pcmdi_month_unforced_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-False-month-False-unforced-False-joint-False-Atlantic', 'rb') as pfile:
    metrics_pcmdi_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-False-unforced-False-joint-False-Atlantic', 'rb') as pfile:
    metrics_pcmdi_stand_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/PCMDI/tos-metrics-stand-True-month-False-unforced-True-joint-False-Atlantic', 'rb') as pfile:
    metrics_pcmdi_unforced_atlantic = pickle.load(pfile)

# %%
with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-False-month-True-unforced-False-joint-False-Atlantic', 'rb') as pfile:
    metrics_ersst_month_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-True-unforced-False-joint-False-Atlantic', 'rb') as pfile:
    metrics_ersst_month_stand_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-True-unforced-True-joint-False-Atlantic', 'rb') as pfile:
    metrics_ersst_month_unforced_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-False-month-False-unforced-False-joint-False-Atlantic', 'rb') as pfile:
    metrics_ersst_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-False-unforced-False-joint-False-Atlantic', 'rb') as pfile:
    metrics_ersst_stand_atlantic = pickle.load(pfile)

with open('/p/lustre2/shiduan/ForceSMIP/EOF/modes_all/1950_2022/ERSST/tos-metrics-stand-True-month-False-unforced-True-joint-False-Atlantic', 'rb') as pfile:
    metrics_ersst_unforced_atlantic = pickle.load(pfile)

# %%
x = np.arange(len(metrics_pcmdi_month['obs_pc']))
y = metrics_pcmdi_month['pc']
y1 = metrics_pcmdi_month['obs_pc']
y2 = metrics_cobe_month['obs_pc']
y3 = metrics_ersst_month['obs_pc']
r, p = pearsonr(y, y1)
plt.plot(x, y1, label='PCMDI '+str(round(r, 2)))
r, p = pearsonr(y, y2)
plt.plot(x, y2, label='COBE '+str(round(r, 2)))
r, p = pearsonr(y, y3)
plt.plot(x, y3, label='ERSST '+str(round(r, 2)))
plt.plot(x, y, label='CMIP6')
plt.legend()
plt.show()

# %%
def get_detection_time(data):# sn
    data = xa.DataArray(data, dims=['time'], coords={'time': np.arange(len(data))})
    data = data.reindex(time=list(reversed(data.time)))
    indices = (data < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = data.time.shape[0]
    back = whole_period-first_indices
    return back.data

# %%
metrics_pcmdi_month_atlantic.keys()

# %%
x_ticks = np.arange(40, 852, 300)
x_ticks

# %%
start = np.datetime64('1950-01')
x_labels = [start+np.timedelta64(i, 'M') for i in x_ticks]
print(x_labels)

# %%
colors = sns.color_palette('deep', 9)
cobe_color = colors[-2]
pcmdi_color = colors[-1]
ersst_color = colors[-3]
x = np.arange(len(metrics_pcmdi_month_atlantic['sn']))
time = metrics_pcmdi_month_atlantic['pc'].time[12:]
x_ticks = np.arange(40, 852, 300)
start_month = np.datetime64('1951-01')
tick_time = [start_month+np.timedelta64(i,'M') for i in x_ticks]
def plot_sn(data, color, label, ax):
    x = np.arange(len(data))
    ax.plot(x, data, label=label+' '+str(round(data[-1], 2)), color=color)
    toe = get_detection_time(data)
    ax.axvline(x=toe, ymin=0, ymax=1, color=color, linewidth=2)

fig, axes = plt.subplots(nrows=3, ncols=6, sharey=True, sharex=True, figsize=(18, 8))
ax = axes.flatten()[0]
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
ax.set_title('AllM-Anomaly')
plot_sn(metrics_pcmdi_atlantic['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_atlantic['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_atlantic['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_atlantic['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[1]
ax.set_title('AllM-StdAnomaly')
plot_sn(metrics_pcmdi_stand_atlantic['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_stand_atlantic['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_stand_atlantic['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_stand_atlantic['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[2]
ax.set_title('AllM-UnforcedAnomaly')
plot_sn(metrics_pcmdi_unforced_atlantic['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_unforced_atlantic['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_unforced_atlantic['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_unforced_atlantic['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[3]
ax.set_title('MbyM-Anomaly')
plot_sn(metrics_pcmdi_month_atlantic['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_month_atlantic['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_month_atlantic['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_month_atlantic['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[4]
ax.set_title('MbyM-StdAnomaly')
plot_sn(metrics_pcmdi_month_stand_atlantic['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_month_stand_atlantic['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_month_stand_atlantic['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_month_stand_atlantic['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[5]
ax.set_title('MbyM-UnforcedAnomaly')
plot_sn(metrics_pcmdi_month_unforced_atlantic['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_month_unforced_atlantic['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_month_unforced_atlantic['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_month_unforced_atlantic['sn'], label='CMIP6', color='black')
ax.legend()
# Global
ax = axes.flatten()[6]
plot_sn(metrics_pcmdi['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[7]
plot_sn(metrics_pcmdi_stand['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_stand['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_stand['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_stand['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[8]
plot_sn(metrics_pcmdi_unforced['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_unforced['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_unforced['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_unforced['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[9]
plot_sn(metrics_pcmdi_month['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_month['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_month['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_month['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[10]
plot_sn(metrics_pcmdi_month_stand['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_month_stand['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_month_stand['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_month_stand['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[11]
plot_sn(metrics_pcmdi_month_unforced['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_month_unforced['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_month_unforced['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_month_unforced['sn'], label='CMIP6', color='black')
ax.legend()
# pacific
ax = axes.flatten()[12]
plot_sn(metrics_pcmdi_pacific['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_pacific['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_pacific['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_pacific['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[13]
plot_sn(metrics_pcmdi_stand_pacific['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_stand_pacific['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_stand_pacific['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_stand_pacific['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[14]
plot_sn(metrics_pcmdi_unforced_pacific['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_unforced_pacific['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_unforced_pacific['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_unforced_pacific['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[15]
plot_sn(metrics_pcmdi_month_pacific['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_month_pacific['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_month_pacific['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_month_pacific['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[16]
plot_sn(metrics_pcmdi_month_stand_pacific['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_month_stand_pacific['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_month_stand_pacific['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_month_stand_pacific['sn'], label='CMIP6', color='black')
ax.legend()
ax = axes.flatten()[17]
plot_sn(metrics_pcmdi_month_unforced_pacific['sn_obs'], color=pcmdi_color, label='PCMDI', ax=ax)
plot_sn(metrics_cobe_month_unforced_pacific['sn_obs'], color=cobe_color, label='COBE', ax=ax)
plot_sn(metrics_ersst_month_unforced_pacific['sn_obs'], color=ersst_color, label='ERSST', ax=ax)
ax.plot(x, metrics_pcmdi_month_unforced_pacific['sn'], label='CMIP6', color='black')
ax.legend()
plt.tight_layout()
plt.annotate('Pacific', xy=(0., 0.15), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
plt.annotate('Global', xy=(0., 0.48), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
plt.annotate('Atlantic', xy=(0, 0.78), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
plt.savefig('SST-SN-basins.png', bbox_inches='tight', dpi=130)
plt.show()

# %% [markdown]
# # PC

# %%
start_month = np.datetime64('1950-01')
pinatubo = np.datetime64('1991-06')
pinatubo_x = (pinatubo-start_month)/np.timedelta64(1, 'M')
print(pinatubo_x)
agung = np.datetime64('1963-02')
agung_x = (agung-start_month)/np.timedelta64(1, 'M')
print(agung_x)
elchichon = np.datetime64('1982-04')
elchichon_x = (elchichon-start_month)/np.timedelta64(1, 'M')

# %%
colors = sns.color_palette('deep', 9)
cobe_color = colors[-2]
pcmdi_color = colors[-1]
ersst_color = colors[-3]
x = np.arange(len(metrics_pcmdi_month_atlantic['pc']))
time = metrics_pcmdi_month_atlantic['pc'].time[:]
x_ticks = np.arange(40, 852, 300)
start_month = np.datetime64('1950-01')
tick_time = [start_month+np.timedelta64(i,'M') for i in x_ticks]
def plot_pc(data, color, label, ax, ref):
    x = np.arange(len(data))
    r, p = pearsonr(data, ref)
    ax.plot(x, data, label=label+' '+str(round(r, 2)), color=color)


fig, axes = plt.subplots(nrows=3, ncols=6, sharey=True, sharex=True, figsize=(18, 8))
ax = axes.flatten()[0]
ax.set_xticks(x_ticks)
ax.set_xticklabels(tick_time)
ax.set_title('AllM-Anomaly')
plot_pc(metrics_pcmdi_atlantic['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_atlantic['pc'])
plot_pc(metrics_cobe_atlantic['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_atlantic['pc'])
plot_pc(metrics_ersst_atlantic['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_atlantic['pc'])
ax.plot(x, metrics_pcmdi_atlantic['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[1]
ax.set_title('AllM-StdAnomaly')
plot_pc(metrics_pcmdi_stand_atlantic['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_stand_atlantic['pc'])
plot_pc(metrics_cobe_stand_atlantic['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_stand_atlantic['pc'])
plot_pc(metrics_ersst_stand_atlantic['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_stand_atlantic['pc'])
ax.plot(x, metrics_pcmdi_stand_atlantic['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[2]
ax.set_title('AllM-UnforcedAnomaly')
plot_pc(metrics_pcmdi_unforced_atlantic['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_unforced_atlantic['pc'])
plot_pc(metrics_cobe_unforced_atlantic['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_unforced_atlantic['pc'])
plot_pc(metrics_ersst_unforced_atlantic['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_unforced_atlantic['pc'])
ax.plot(x, metrics_pcmdi_unforced_atlantic['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[3]
ax.set_title('MbyM-Anomaly')
plot_pc(metrics_pcmdi_month_atlantic['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_month_atlantic['pc'])
plot_pc(metrics_cobe_month_atlantic['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_month_atlantic['pc'])
plot_pc(metrics_ersst_month_atlantic['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_month_atlantic['pc'])
ax.plot(x, metrics_pcmdi_month_atlantic['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[4]
ax.set_title('MbyM-StdAnomaly')
plot_pc(metrics_pcmdi_month_stand_atlantic['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_month_stand_atlantic['pc'])
plot_pc(metrics_cobe_month_stand_atlantic['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_month_stand_atlantic['pc'])
plot_pc(metrics_ersst_month_stand_atlantic['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_month_stand_atlantic['pc'])
ax.plot(x, metrics_pcmdi_month_stand_atlantic['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[5]
ax.set_title('MbyM-UnforcedAnomaly')
plot_pc(metrics_pcmdi_month_unforced_atlantic['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_month_unforced_atlantic['pc'])
plot_pc(metrics_cobe_month_unforced_atlantic['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_month_unforced_atlantic['pc'])
plot_pc(metrics_ersst_month_unforced_atlantic['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_month_unforced_atlantic['pc'])
ax.plot(x, metrics_pcmdi_month_unforced_atlantic['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
# Global
ax = axes.flatten()[6]
plot_pc(metrics_pcmdi['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi['pc'])
plot_pc(metrics_cobe['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi['pc'])
plot_pc(metrics_ersst['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi['pc'])
ax.plot(x, metrics_pcmdi['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[7]
plot_pc(metrics_pcmdi_stand['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_stand['pc'])
plot_pc(metrics_cobe_stand['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_stand['pc'])
plot_pc(metrics_ersst_stand['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_stand['pc'])
ax.plot(x, metrics_pcmdi_stand['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[8]
plot_pc(metrics_pcmdi_unforced['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_unforced['pc'])
plot_pc(metrics_cobe_unforced['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_unforced['pc'])
plot_pc(metrics_ersst_unforced['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_unforced['pc'])
ax.plot(x, metrics_pcmdi_unforced['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[9]
plot_pc(metrics_pcmdi_month['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_month['pc'])
plot_pc(metrics_cobe_month['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_month['pc'])
plot_pc(metrics_ersst_month['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_month['pc'])
ax.plot(x, metrics_pcmdi_month['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[10]
plot_pc(metrics_pcmdi_month_stand['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_month_stand['pc'])
plot_pc(metrics_cobe_month_stand['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_month_stand['pc'])
plot_pc(metrics_ersst_month_stand['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_month_stand['pc'])
ax.plot(x, metrics_pcmdi_month_stand['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[11]
plot_pc(metrics_pcmdi_month_unforced['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_month_unforced['pc'])
plot_pc(metrics_cobe_month_unforced['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_month_unforced['pc'])
plot_pc(metrics_ersst_month_unforced['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_month_unforced['pc'])
ax.plot(x, metrics_pcmdi_month_unforced['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
# pacific
ax = axes.flatten()[12]
plot_pc(metrics_pcmdi_pacific['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_pacific['pc'])
plot_pc(metrics_cobe_pacific['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_pacific['pc'])
plot_pc(metrics_ersst_pacific['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_pacific['pc'])
ax.plot(x, metrics_pcmdi_pacific['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[13]
plot_pc(metrics_pcmdi_stand_pacific['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_stand_pacific['pc'])
plot_pc(metrics_cobe_stand_pacific['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_stand_pacific['pc'])
plot_pc(metrics_ersst_stand_pacific['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_stand_pacific['pc'])
ax.plot(x, metrics_pcmdi_stand_pacific['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[14]
plot_pc(metrics_pcmdi_unforced_pacific['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_unforced_pacific['pc'])
plot_pc(metrics_cobe_unforced_pacific['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_unforced_pacific['pc'])
plot_pc(metrics_ersst_unforced_pacific['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_unforced_pacific['pc'])
ax.plot(x, metrics_pcmdi_unforced_pacific['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[15]
plot_pc(metrics_pcmdi_month_pacific['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_month_pacific['pc'])
plot_pc(metrics_cobe_month_pacific['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_month_pacific['pc'])
plot_pc(metrics_ersst_month_pacific['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_month_pacific['pc'])
ax.plot(x, metrics_pcmdi_month_pacific['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[16]
plot_pc(metrics_pcmdi_month_stand_pacific['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_month_stand_pacific['pc'])
plot_pc(metrics_cobe_month_stand_pacific['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_month_stand_pacific['pc'])
plot_pc(metrics_ersst_month_stand_pacific['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_month_stand_pacific['pc'])
ax.plot(x, metrics_pcmdi_month_stand_pacific['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
ax = axes.flatten()[17]
plot_pc(metrics_pcmdi_month_unforced_pacific['obs_pc'], color=pcmdi_color, label='PCMDI', ax=ax, ref=metrics_pcmdi_month_unforced_pacific['pc'])
plot_pc(metrics_cobe_month_unforced_pacific['obs_pc'], color=cobe_color, label='COBE', ax=ax, ref=metrics_pcmdi_month_unforced_pacific['pc'])
plot_pc(metrics_ersst_month_unforced_pacific['obs_pc'], color=ersst_color, label='ERSST', ax=ax, ref=metrics_pcmdi_month_unforced_pacific['pc'])
ax.plot(x, metrics_pcmdi_month_unforced_pacific['pc'], label='CMIP6', color='black')
ax.axvline(x=pinatubo_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=agung_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.axvline(x=elchichon_x, ymin=0, ymax=1, color='black', alpha=.2, linestyle='dashed')
ax.legend()
plt.tight_layout()
plt.annotate('Pacific', xy=(0., 0.15), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
plt.annotate('Global', xy=(0., 0.48), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
plt.annotate('Atlantic', xy=(0, 0.78), xycoords='figure fraction', fontsize=12, rotation=90, weight='bold')
plt.savefig('SST-PC-basins.png', bbox_inches='tight', dpi=130)
plt.show()

# %% [markdown]
# # detection time

# %%
start_month = metrics_cobe_atlantic['pc'].time.data[12]
print(start_month)
start_month = np.datetime64('1951-01')

# %%
metrics = metrics_cobe_atlantic
time = metrics_cobe_atlantic['pc'].time.data[12:]
upper = np.array(metrics['s_obs_list'])+np.array(metrics['obs_se'])
lower = np.array(metrics['s_obs_list'])-np.array(metrics['obs_se'])
center = np.array(metrics['s_obs_list'])
upper = upper/np.array(metrics['n_list'])
lower = lower/np.array(metrics['n_list'])
center = center/np.array(metrics['n_list'])
upper = xa.DataArray(upper, dims=['time'], coords={'time': time})
lower = xa.DataArray(lower, dims=['time'], coords={'time': time})
center = xa.DataArray(center, dims=['time'], coords={'time': time})

# %%
def get_detection_obs(metrics):
    time = list(metrics_cobe_atlantic['pc'].time.data[12:])
    upper = np.array(metrics['s_obs_list'])+np.array(metrics['obs_se'])
    lower = np.array(metrics['s_obs_list'])-np.array(metrics['obs_se'])
    center = np.array(metrics['s_obs_list'])
    upper = upper/np.array(metrics['n_list'])
    lower = lower/np.array(metrics['n_list'])
    center = center/np.array(metrics['n_list'])
    upper = xa.DataArray(upper, dims=['time'], coords={'time': time})
    lower = xa.DataArray(lower, dims=['time'], coords={'time': time})
    center = xa.DataArray(center, dims=['time'], coords={'time': time})

    upper = upper.reindex(time=list(reversed(upper.time.data)))
    lower = lower.reindex(time=list(reversed(lower.time.data)))
    center = center.reindex(time=list(reversed(center.time.data)))

    indices = (upper < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = upper.time.shape[0]
    back = whole_period-first_indices
    if back<whole_period:
        detect_time_upper = back
    else:
        detect_time_upper = None
    
    indices = (lower < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = lower.time.shape[0]
    back = whole_period-first_indices
    if back<whole_period:
        detect_time_lower = back
    else:
        detect_time_lower = None

    indices = (center < 2)
    first_indices = (indices.argmax(dim='time'))
    whole_period = center.time.shape[0]
    back = whole_period-first_indices
    if back<whole_period:
        detect_time_center = back
    else:
        detect_time_center = None
    return detect_time_lower, detect_time_center, detect_time_upper

# %%
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_atlantic)
print(start_month+np.timedelta64(int(detect_time_center.data), 'M'))

# %%
atlantic_time_all = []
atlantic_ersst = []
atlantic_pcmdi = []
atlantic_cobe = []

detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_atlantic)
atlantic_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_month_atlantic)
atlantic_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_stand_atlantic)
atlantic_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_month_stand_atlantic)
atlantic_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_unforced_atlantic)
atlantic_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_month_unforced_atlantic)
atlantic_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))

detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_atlantic)
atlantic_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_month_atlantic)
atlantic_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_stand_atlantic)
atlantic_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_month_stand_atlantic)
atlantic_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_unforced_atlantic)
atlantic_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_month_unforced_atlantic)
atlantic_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))

detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_atlantic)
atlantic_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_month_atlantic)
atlantic_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_stand_atlantic)
atlantic_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_month_stand_atlantic)
atlantic_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_unforced_atlantic)
atlantic_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_month_unforced_atlantic)
atlantic_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))

# %%
global_time_all = []
global_ersst = []
global_cobe = []
global_pcmdi = []

detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe)
global_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_month)
global_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_stand)
global_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_month_stand)
global_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_unforced)
global_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_month_unforced)
global_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))

detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi)
global_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_month)
global_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_stand)
global_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_month_stand)
global_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_unforced)
global_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_month_unforced)
global_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))

detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst)
global_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_month)
global_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_stand)
global_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_month_stand)
global_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_unforced)
global_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_month_unforced)
global_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))

# %%
# pacific_time_all = []
pacific_cobe = []
pacific_ersst = []
pacific_pcmdi = []

detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_pacific)
pacific_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_month_pacific)
pacific_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_stand_pacific)
pacific_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_month_stand_pacific)
pacific_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_unforced_pacific)
pacific_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_cobe_month_unforced_pacific)
pacific_cobe.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))

detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_pacific)
pacific_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_month_pacific)
pacific_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_stand_pacific)
pacific_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_month_stand_pacific)
pacific_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_unforced_pacific)
pacific_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_pcmdi_month_unforced_pacific)
pacific_pcmdi.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))

detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_pacific)
pacific_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_month_pacific)
pacific_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_stand_pacific)
pacific_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_month_stand_pacific)
pacific_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_unforced_pacific)
pacific_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))
detect_time_lower, detect_time_center, detect_time_upper = get_detection_obs(metrics_ersst_month_unforced_pacific)
pacific_ersst.append(start_month+np.timedelta64(int(detect_time_center.data), 'M'))

# %%
global_sn = []

global_sn.append(metrics_cobe['sn_obs'][-1])
global_sn.append(metrics_cobe_month['sn_obs'][-1])
global_sn.append(metrics_cobe_stand['sn_obs'][-1])
global_sn.append(metrics_cobe_month_stand['sn_obs'][-1])
global_sn.append(metrics_cobe_unforced['sn_obs'][-1])
global_sn.append(metrics_cobe_month_unforced['sn_obs'][-1])

global_sn.append(metrics_pcmdi['sn_obs'][-1])
global_sn.append(metrics_pcmdi_month['sn_obs'][-1])
global_sn.append(metrics_pcmdi_stand['sn_obs'][-1])
global_sn.append(metrics_pcmdi_month_stand['sn_obs'][-1])
global_sn.append(metrics_pcmdi_unforced['sn_obs'][-1])
global_sn.append(metrics_pcmdi_month_unforced['sn_obs'][-1])

global_sn.append(metrics_ersst['sn_obs'][-1])
global_sn.append(metrics_ersst_month['sn_obs'][-1])
global_sn.append(metrics_ersst_stand['sn_obs'][-1])
global_sn.append(metrics_ersst_month_stand['sn_obs'][-1])
global_sn.append(metrics_ersst_unforced['sn_obs'][-1])
global_sn.append(metrics_ersst_month_unforced['sn_obs'][-1])

# %%
atlantic_sn = []

atlantic_sn.append(metrics_cobe_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_cobe_month_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_cobe_stand_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_cobe_month_stand_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_cobe_unforced_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_cobe_month_unforced_atlantic['sn_obs'][-1])

atlantic_sn.append(metrics_pcmdi_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_pcmdi_month_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_pcmdi_stand_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_pcmdi_month_stand_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_pcmdi_unforced_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_pcmdi_month_unforced_atlantic['sn_obs'][-1])

atlantic_sn.append(metrics_ersst_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_ersst_month_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_ersst_stand_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_ersst_month_stand_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_ersst_unforced_atlantic['sn_obs'][-1])
atlantic_sn.append(metrics_ersst_month_unforced_atlantic['sn_obs'][-1])

# %%
pacific_sn = []

pacific_sn.append(metrics_cobe_pacific['sn_obs'][-1])
pacific_sn.append(metrics_cobe_month_pacific['sn_obs'][-1])
pacific_sn.append(metrics_cobe_stand_pacific['sn_obs'][-1])
pacific_sn.append(metrics_cobe_month_stand_pacific['sn_obs'][-1])
pacific_sn.append(metrics_cobe_unforced_pacific['sn_obs'][-1])
pacific_sn.append(metrics_cobe_month_unforced_pacific['sn_obs'][-1])

pacific_sn.append(metrics_pcmdi_pacific['sn_obs'][-1])
pacific_sn.append(metrics_pcmdi_month_pacific['sn_obs'][-1])
pacific_sn.append(metrics_pcmdi_stand_pacific['sn_obs'][-1])
pacific_sn.append(metrics_pcmdi_month_stand_pacific['sn_obs'][-1])
pacific_sn.append(metrics_pcmdi_unforced_pacific['sn_obs'][-1])
pacific_sn.append(metrics_pcmdi_month_unforced_pacific['sn_obs'][-1])

pacific_sn.append(metrics_ersst_pacific['sn_obs'][-1])
pacific_sn.append(metrics_ersst_month_pacific['sn_obs'][-1])
pacific_sn.append(metrics_ersst_stand_pacific['sn_obs'][-1])
pacific_sn.append(metrics_ersst_month_stand_pacific['sn_obs'][-1])
pacific_sn.append(metrics_ersst_unforced_pacific['sn_obs'][-1])
pacific_sn.append(metrics_ersst_month_unforced_pacific['sn_obs'][-1])

# %%
plt.boxplot(global_sn, positions=[0])
plt.boxplot(atlantic_sn, positions=[2])
plt.boxplot(pacific_sn, positions=[4])
plt.xticks([0, 2, 4], ['Global', 'Atlantic', 'Pacific'])
plt.show()

# %%
global_corr = []
r, p = pearsonr(metrics_cobe['obs_pc'], metrics_cobe['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_cobe_month['obs_pc'], metrics_cobe_month['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_cobe_stand['obs_pc'], metrics_cobe_stand['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_cobe_month_stand['obs_pc'], metrics_cobe_month_stand['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_cobe_unforced['obs_pc'], metrics_cobe_unforced['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_cobe_month_unforced['obs_pc'], metrics_cobe_month_unforced['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_ersst['obs_pc'], metrics_ersst['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_ersst_month['obs_pc'], metrics_ersst_month['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_ersst_stand['obs_pc'], metrics_ersst_stand['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_ersst_month_stand['obs_pc'], metrics_ersst_month_stand['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_ersst_unforced['obs_pc'], metrics_ersst_unforced['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_ersst_month_unforced['obs_pc'], metrics_ersst_month_unforced['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_pcmdi['obs_pc'], metrics_pcmdi['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_pcmdi_month['obs_pc'], metrics_pcmdi_month['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_pcmdi_stand['obs_pc'], metrics_pcmdi_stand['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_pcmdi_month_stand['obs_pc'], metrics_pcmdi_month_stand['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_pcmdi_unforced['obs_pc'], metrics_pcmdi_unforced['pc'])
global_corr.append(r)
r, p = pearsonr(metrics_pcmdi_month_unforced['obs_pc'], metrics_pcmdi_month_unforced['pc'])
global_corr.append(r)

# %%
pacific_corr = []
r, p = pearsonr(metrics_cobe_pacific['obs_pc'], metrics_cobe_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_cobe_month_pacific['obs_pc'], metrics_cobe_month_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_cobe_stand_pacific['obs_pc'], metrics_cobe_stand_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_cobe_month_stand_pacific['obs_pc'], metrics_cobe_month_stand_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_cobe_unforced_pacific['obs_pc'], metrics_cobe_unforced_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_cobe_month_unforced_pacific['obs_pc'], metrics_cobe_month_unforced_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_ersst_pacific['obs_pc'], metrics_ersst_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_ersst_month_pacific['obs_pc'], metrics_ersst_month_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_ersst_stand_pacific['obs_pc'], metrics_ersst_stand_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_ersst_month_stand_pacific['obs_pc'], metrics_ersst_month_stand_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_ersst_unforced_pacific['obs_pc'], metrics_ersst_unforced_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_ersst_month_unforced_pacific['obs_pc'], metrics_ersst_month_unforced_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_pcmdi_pacific['obs_pc'], metrics_pcmdi_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_pcmdi_month_pacific['obs_pc'], metrics_pcmdi_month_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_pcmdi_stand_pacific['obs_pc'], metrics_pcmdi_stand_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_pcmdi_month_stand_pacific['obs_pc'], metrics_pcmdi_month_stand_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_pcmdi_unforced_pacific['obs_pc'], metrics_pcmdi_unforced_pacific['pc'])
pacific_corr.append(r)
r, p = pearsonr(metrics_pcmdi_month_unforced_pacific['obs_pc'], metrics_pcmdi_month_unforced_pacific['pc'])
pacific_corr.append(r)

# %%
atlantic_corr = []
r, p = pearsonr(metrics_cobe_atlantic['obs_pc'], metrics_cobe_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_cobe_month_atlantic['obs_pc'], metrics_cobe_month_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_cobe_stand_atlantic['obs_pc'], metrics_cobe_stand_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_cobe_month_stand_atlantic['obs_pc'], metrics_cobe_month_stand_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_cobe_unforced_atlantic['obs_pc'], metrics_cobe_unforced_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_cobe_month_unforced_atlantic['obs_pc'], metrics_cobe_month_unforced_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_ersst_atlantic['obs_pc'], metrics_ersst_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_ersst_month_atlantic['obs_pc'], metrics_ersst_month_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_ersst_stand_atlantic['obs_pc'], metrics_ersst_stand_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_ersst_month_stand_atlantic['obs_pc'], metrics_ersst_month_stand_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_ersst_unforced_atlantic['obs_pc'], metrics_ersst_unforced_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_ersst_month_unforced_atlantic['obs_pc'], metrics_ersst_month_unforced_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_pcmdi_atlantic['obs_pc'], metrics_pcmdi_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_pcmdi_month_atlantic['obs_pc'], metrics_pcmdi_month_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_pcmdi_stand_atlantic['obs_pc'], metrics_pcmdi_stand_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_pcmdi_month_stand_atlantic['obs_pc'], metrics_pcmdi_month_stand_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_pcmdi_unforced_atlantic['obs_pc'], metrics_pcmdi_unforced_atlantic['pc'])
atlantic_corr.append(r)
r, p = pearsonr(metrics_pcmdi_month_unforced_atlantic['obs_pc'], metrics_pcmdi_month_unforced_atlantic['pc'])
atlantic_corr.append(r)

# %%
plt.boxplot(global_corr, positions=[0])
plt.boxplot(pacific_corr, positions=[2])
plt.boxplot(atlantic_corr, positions=[4])

# %%
plt.plot(global_ersst)

# %%
from matplotlib.lines import Line2D
import seaborn as sns
fig = plt.figure(figsize=(10, 4))

ax = fig.add_subplot(122)
ax.scatter(atlantic_ersst[::2], pacific_ersst[::2], color='tab:blue', marker='x', label='Pacific-ERSST')
ax.scatter(atlantic_pcmdi[::2], pacific_pcmdi[::2], color='tab:blue', marker='o', facecolor='none', label='Pacific-PCMDI')
ax.scatter(atlantic_cobe[::2], pacific_cobe[::2], color='tab:blue', marker='s', label='Pacific-COBE')
ax.scatter(atlantic_ersst[::2], global_ersst[::2], color='tab:red', marker='x', label='Pacific-ERSST')
ax.scatter(atlantic_pcmdi[::2], global_pcmdi[::2], color='tab:red', marker='o', facecolor='none', label='Pacific-PCMDI')
ax.scatter(atlantic_cobe[::2], global_cobe[::2], color='tab:red', marker='s', label='Pacific-COBE')
ax.plot([np.datetime64('1978-01'), np.datetime64('1998-01')], [np.datetime64('1978-01'), np.datetime64('1998-01')], 
         color='black')

legend_elements = [Line2D([0], [0], marker='x', markersize=5, color='k', lw=0, label='ERSST'),
                   Line2D([0], [0], marker='o', markersize=5, color='k', lw=0, label='PCMDI',
                          markerfacecolor='none'),
                   Line2D([0], [0], marker='s', markersize=5, color='k', lw=0, label='COBE'),
                   Line2D([0], [0], color='tab:red', label='Global/Atlantic'), 
                   Line2D([0], [0], color='tab:blue', label='Pacific/Atlantic')]
ax.legend(handles=legend_elements, ncol=2)
ax.set_xlabel('Atlantic')
ax.set_ylabel('Pacific/Global')
ax.set_title('ToE')
ax = fig.add_subplot(121)
b1 = ax.boxplot(global_corr, positions=[0])
b2 = ax.boxplot(atlantic_corr, positions=[2], showfliers=False)
b3 = ax.boxplot(pacific_corr, positions=[4], showfliers=False)
for _, line_list in b1.items():
    for line in line_list:
       line.set_color('tab:orange')
for _, line_list in b2.items():
    for line in line_list:
       line.set_color('tab:orange')
for _, line_list in b3.items():
    for line in line_list:
       line.set_color('tab:orange')
ax.set_title('Correlation Coefficients/SNR')
ax.set_ylabel('Correlation Coefficients')
ax1 = ax.twinx()
ax1.set_ylabel('SNR')
b1 = ax1.boxplot(global_sn, positions=[.3])
b2 = ax1.boxplot(atlantic_sn, positions=[2.3], showfliers=False)
b3 = ax1.boxplot(pacific_sn, positions=[4.3], showfliers=False)
for _, line_list in b1.items():
    for line in line_list:
       line.set_color('tab:grey')
for _, line_list in b2.items():
    for line in line_list:
       line.set_color('tab:grey')
for _, line_list in b3.items():
    for line in line_list:
       line.set_color('tab:grey')
ax.set_xticks([0.1, 2.1, 4.1], ['Global', 'Atlantic', 'Pacific'])
plt.tight_layout()
fig.text(0.03, .94, 'A)', weight='bold')
fig.text(0.53, .94, 'B)', weight='bold')
plt.savefig('tos-basin-ToE-SNR.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
sns.color_palette('Set3', 10)
